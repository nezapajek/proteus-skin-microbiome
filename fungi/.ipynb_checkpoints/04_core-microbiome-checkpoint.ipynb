# %% [markdown]
# # FUNGI

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# %matplotlib inline

# %%
#import packages
import os
import qiime2 as q2
import pandas as pd
from qiime2.plugins import feature_table
from qiime2.plugins.taxa.methods import collapse
from qiime2.plugins.feature_table.visualizers import core_features

# %%
# define workdir
# %env WORKDIR /home/nezapa/qiime-thesis
WORKDIR = os.environ.get("WORKDIR")
# Out:
# env: WORKDIR=/home/nezapa/qiime-thesis

# %%
# import data
denoisetable_fun = q2.Artifact.load('./results/denoisetable_fun.qza')
rep_seqs_fun = q2.Artifact.load('./results/rep_seqs_fun.qza')
denoising_stats = q2.Artifact.load('./results/denoising_stats.qza')
sample_metadata = q2.Metadata.load('../00.sample-metadata.tsv')
taxonomy = q2.Artifact.load('./results/taxonomy_vsearch.qza')

# %% [markdown]
# ### CORE MICROBIOME

# %%
core_microbiome_asv = feature_table.actions.core_features(
    table = denoisetable_fun,
    min_fraction = 0.5,
    steps = 6
)

# %%
taxtable ={}

for level in range(2,8):
    result = collapse(
        table = denoisetable_fun,
        taxonomy = taxonomy,
        level = level
    )
    taxtable[level] = result.collapsed_table

# %%
taxtable[5].view(pd.DataFrame).T
# Out:
#                                                       P01A  P03A    P05A  \
# k__Fungi;p__Ascomycota;c__Sordariomycetes;o__Hy...     0.0   0.0    16.0
# k__Fungi;p__Basidiomycota;c__Malasseziomycetes;...  9532.0   0.0  9803.0
# k__Fungi;p__Ascomycota;c__Sordariomycetes;__;__        0.0   0.0     0.0
# k__Fungi;p__Ascomycota;c__Eurotiomycetes;o__Eur...   132.0   8.0    23.0
# k__Fungi;p__Basidiomycota;c__Tremellomycetes;o_...     0.0   0.0     0.0
# ...                                                    ...   ...     ...
# k__Fungi;p__Ascomycota;c__Eurotiomycetes;o__Cha...     0.0   0.0     0.0
# k__Fungi;p__Basidiomycota;c__Agaricomycetes;o__...     3.0   0.0  2397.0
# k__Fungi;p__Basidiomycota;c__Agaricomycetes;o__...     0.0   0.0     0.0
# k__Fungi;p__Basidiomycota;c__Exobasidiomycetes;...     0.0   0.0     0.0
# k__Fungi;p__Basidiomycota;c__Agaricomycetes;o__...     0.0   0.0     0.0
#
#                                                       P07A  P09A  P11A  \
# k__Fungi;p__Ascomycota;c__Sordariomycetes;o__Hy...     0.0   0.0  35.0
# k__Fungi;p__Basidiomycota;c__Malasseziomycetes;...  4726.0   0.0   0.0
# k__Fungi;p__Ascomycota;c__Sordariomycetes;__;__        0.0   0.0   0.0
# k__Fungi;p__Ascomycota;c__Eurotiomycetes;o__Eur...    15.0   0.0   3.0
# k__Fungi;p__Basidiomycota;c__Tremellomycetes;o_...     0.0   0.0   0.0
# ...                                                    ...   ...   ...
# k__Fungi;p__Ascomycota;c__Eurotiomycetes;o__Cha...     0.0   0.0   0.0
# k__Fungi;p__Basidiomycota;c__Agaricomycetes;o__...     0.0   0.0   0.0
# k__Fungi;p__Basidiomycota;c__Agaricomycetes;o__...     0.0   0.0   0.0
# k__Fungi;p__Basidiomycota;c__Exobasidiomycetes;...     0.0   0.0   0.0
# k__Fungi;p__Basidiomycota;c__Agaricomycetes;o__...     0.0   0.0   0.0
#
#                                                        P13A    P15A  P17A  \
# k__Fungi;p__Ascomycota;c__Sordariomycetes;o__Hy...  33117.0  3195.0   0.0
# k__Fungi;p__Basidiomycota;c__Malasseziomycetes;...      2.0    18.0   2.0
# k__Fungi;p__Ascomycota;c__Sordariomycetes;__;__         0.0     0.0   0.0
# k__Fungi;p__Ascomycota;c__Eurotiomycetes;o__Eur...      7.0     0.0   0.0
# k__Fungi;p__Basidiomycota;c__Tremellomycetes;o_...      0.0     0.0   0.0
# ...                                                     ...     ...   ...
# k__Fungi;p__Ascomycota;c__Eurotiomycetes;o__Cha...      0.0     0.0   0.0
# k__Fungi;p__Basidiomycota;c__Agaricomycetes;o__...      0.0     0.0   0.0
# k__Fungi;p__Basidiomycota;c__Agaricomycetes;o__...      0.0     0.0   0.0
# k__Fungi;p__Basidiomycota;c__Exobasidiomycetes;...      0.0     0.0   0.0
# k__Fungi;p__Basidiomycota;c__Agaricomycetes;o__...      0.0     0.0   0.0
#
#                                                        P19A  P20A    P21A  \
# k__Fungi;p__Ascomycota;c__Sordariomycetes;o__Hy...      0.0   0.0     5.0
# k__Fungi;p__Basidiomycota;c__Malasseziomycetes;...  10753.0   0.0     4.0
# k__Fungi;p__Ascomycota;c__Sordariomycetes;__;__       433.0   0.0     0.0
# k__Fungi;p__Ascomycota;c__Eurotiomycetes;o__Eur...   2396.0   6.0  2541.0
# k__Fungi;p__Basidiomycota;c__Tremellomycetes;o_...    583.0   0.0   856.0
# ...                                                     ...   ...     ...
# k__Fungi;p__Ascomycota;c__Eurotiomycetes;o__Cha...    735.0   0.0     0.0
# k__Fungi;p__Basidiomycota;c__Agaricomycetes;o__...      0.0   0.0     2.0
# k__Fungi;p__Basidiomycota;c__Agaricomycetes;o__...      0.0   0.0   824.0
# k__Fungi;p__Basidiomycota;c__Exobasidiomycetes;...      0.0   0.0  1925.0
# k__Fungi;p__Basidiomycota;c__Agaricomycetes;o__...      0.0   0.0     0.0
#
#                                                      P22A
# k__Fungi;p__Ascomycota;c__Sordariomycetes;o__Hy...   36.0
# k__Fungi;p__Basidiomycota;c__Malasseziomycetes;...    0.0
# k__Fungi;p__Ascomycota;c__Sordariomycetes;__;__       0.0
# k__Fungi;p__Ascomycota;c__Eurotiomycetes;o__Eur...    1.0
# k__Fungi;p__Basidiomycota;c__Tremellomycetes;o_...    0.0
# ...                                                   ...
# k__Fungi;p__Ascomycota;c__Eurotiomycetes;o__Cha...    0.0
# k__Fungi;p__Basidiomycota;c__Agaricomycetes;o__...    0.0
# k__Fungi;p__Basidiomycota;c__Agaricomycetes;o__...    0.0
# k__Fungi;p__Basidiomycota;c__Exobasidiomycetes;...    0.0
# k__Fungi;p__Basidiomycota;c__Agaricomycetes;o__...  527.0
#
# [69 rows x 13 columns]

# %%
core_microbiome ={}

for level in range(2,8):
    result = core_features(
        table = taxtable[level],
        min_fraction = 0.5,
        steps = 6       
    )
    core_microbiome[level] = result.visualization
