# %% [markdown]
# # BACTERIA

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### ALPHA & BETA DIVERSITY
# 1. make a MAFFT tree
# 2. alpha rarefaction
# 3. alpha diversity
# 4. beta diversity

# %%
#import packages
import os
import dokdo
import qiime2 as q2
import seaborn as sns
import pandas as pd
import plotnine as p9
import matplotlib.pyplot as plt
from qiime2.plugins import phylogeny
from qiime2.plugins import diversity
from skbio import DistanceMatrix
import qiime2.plugins.phylogeny.actions as phylogeny_actions

# %%
# define workdir
# %env WORKDIR /home/nezapa/qiime-thesis
WORKDIR = os.environ.get("WORKDIR")
# Out:
# env: WORKDIR=/home/nezapa/qiime-thesis

# %%
# import data
denoisetable_ba = q2.Artifact.load('./results/denoisetable_ba.qza')
rep_seqs_ba = q2.Artifact.load('./results/rep_seqs_ba.qza')
denoising_stats = q2.Artifact.load('./results/denoising_stats.qza')
sample_metadata = q2.Metadata.load('../00.sample-metadata.tsv')

# %% [markdown]
# ## TREE

# %%
action_results = phylogeny_actions.align_to_tree_mafft_fasttree(
    sequences=rep_seqs_ba,
)
aligned_rep_seqs = action_results.alignment
masked_aligned_rep_seqs = action_results.masked_alignment
unrooted_tree = action_results.tree
rooted_tree = action_results.rooted_tree
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: mafft --preservecase --inputorder --thread 1 /tmp/qiime2-archive-faxe4sfv/2be7cabd-943d-4b6c-a51f-13e6a1b3af22/data/dna-sequences.fasta
# inputfile = orig
# 416 x 260 - 260 d
# nthread = 1
# nthreadpair = 1
# nthreadtb = 1
# ppenalty_ex = 0
# stacksize: 8192 kb
# generating a scoring matrix for nucleotide (dist=200) ... done
# Gap Penalty = -1.53, +0.00, +0.00
#
#
#
# Making a distance matrix ..
#   401 / 416 (thread    0)
# done.
#
# Constructing a UPGMA tree (efffree=0) ...
#   410 / 416
# done.
#
# Progressive alignment 1/2...
# STEP    43 / 415 (thread    0)
# Reallocating..done. *alloclen = 1525
# STEP   415 / 415 (thread    0) h
# done.
#
# Making a distance matrix from msa..
#   400 / 416 (thread    0)
# done.
#
# Constructing a UPGMA tree (efffree=1) ...
#   410 / 416
# done.
#
# Progressive alignment 2/2...
# STEP   194 / 415 (thread    0)
# Reallocating..done. *alloclen = 1521
# STEP   415 / 415 (thread    0) h
# done.
#
# disttbfast (nuc) Version 7.505
# alg=A, model=DNA200 (2), 1.53 (4.59), -0.00 (-0.00), noshift, amax=0.0
# 1 thread(s)
#
#
# Strategy:
#  FFT-NS-2 (Fast but rough)
#  Progressive method (guide trees were built 2 times.)
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: FastTree -quote -nt /tmp/qiime2-archive-5nvmzvil/68bd270d-caa1-4bf6-bc79-216747ed124c/data/aligned-dna-sequences.fasta
# FastTree Version 2.1.10 Double precision (No SSE3)
# Alignment: /tmp/qiime2-archive-5nvmzvil/68bd270d-caa1-4bf6-bc79-216747ed124c/data/aligned-dna-sequences.fasta
# Nucleotide distances: Jukes-Cantor Joins: balanced Support: SH-like 1000
# Search: Normal +NNI +SPR (2 rounds range 10) +ML-NNI opt-each=1
# TopHits: 1.00*sqrtN close=default refresh=0.80
# ML Model: Jukes-Cantor, CAT approximation with 20 rate categories
#       0.14 seconds: Joined    100 of    400
#       0.28 seconds: Joined    300 of    400
# Initial topology in 0.35 seconds
# Refining topology: 35 rounds ME-NNIs, 2 rounds ME-SPRs, 17 rounds ML-NNIs
#       0.38 seconds: ME NNI round 2 of 35, 301 of 401 splits, 30 changes (max delta 0.133)
#       0.54 seconds: SPR round   1 of   2, 101 of 804 nodes
#       0.75 seconds: SPR round   1 of   2, 301 of 804 nodes
#       0.86 seconds: SPR round   1 of   2, 401 of 804 nodes
#       0.98 seconds: SPR round   1 of   2, 501 of 804 nodes
#       1.10 seconds: SPR round   1 of   2, 601 of 804 nodes
#       1.21 seconds: SPR round   1 of   2, 701 of 804 nodes
#       1.34 seconds: SPR round   1 of   2, 801 of 804 nodes
#       1.50 seconds: SPR round   2 of   2, 101 of 804 nodes
#       1.60 seconds: SPR round   2 of   2, 201 of 804 nodes
#       1.71 seconds: SPR round   2 of   2, 301 of 804 nodes
#       1.81 seconds: SPR round   2 of   2, 401 of 804 nodes
#       1.94 seconds: SPR round   2 of   2, 501 of 804 nodes
#       2.06 seconds: SPR round   2 of   2, 601 of 804 nodes
#       2.17 seconds: SPR round   2 of   2, 701 of 804 nodes
#       2.30 seconds: SPR round   2 of   2, 801 of 804 nodes
# Total branch-length 31.926 after 2.38 sec
#       2.45 seconds: ML Lengths 101 of 401 splits
#       2.58 seconds: ML Lengths 301 of 401 splits
#       2.91 seconds: ML NNI round 1 of 17, 101 of 401 splits, 16 changes (max delta 5.052)
#       3.18 seconds: ML NNI round 1 of 17, 201 of 401 splits, 35 changes (max delta 5.052)
#       3.45 seconds: ML NNI round 1 of 17, 301 of 401 splits, 57 changes (max delta 7.112)
# ML-NNI round 1: LogLk = -31848.284 NNIs 78 max delta 8.56 Time 3.72
#       3.73 seconds: Site likelihoods with rate category 1 of 20
#       3.83 seconds: Site likelihoods with rate category 13 of 20
# Switched to using 20 rate categories (CAT approximation)
# Rate categories were divided by 0.899 so that average rate = 1.0
# CAT-based log-likelihoods may not be comparable across runs
# Use -gamma for approximate but comparable Gamma(20) log-likelihoods
#       4.10 seconds: ML NNI round 2 of 17, 101 of 401 splits, 7 changes (max delta 1.819)
#       4.30 seconds: ML NNI round 2 of 17, 201 of 401 splits, 16 changes (max delta 4.072)
#       4.48 seconds: ML NNI round 2 of 17, 301 of 401 splits, 24 changes (max delta 5.006)
# ML-NNI round 2: LogLk = -28797.084 NNIs 39 max delta 5.01 Time 4.70
#       4.70 seconds: ML NNI round 3 of 17, 1 of 401 splits
#       4.86 seconds: ML NNI round 3 of 17, 101 of 401 splits, 7 changes (max delta 4.023)
#       5.04 seconds: ML NNI round 3 of 17, 201 of 401 splits, 10 changes (max delta 4.023)
# ML-NNI round 3: LogLk = -28772.431 NNIs 12 max delta 5.18 Time 5.20
#       5.20 seconds: ML NNI round 4 of 17, 1 of 401 splits
#       5.36 seconds: ML NNI round 4 of 17, 101 of 401 splits, 2 changes (max delta 0.503)
# ML-NNI round 4: LogLk = -28769.396 NNIs 3 max delta 0.50 Time 5.46
# ML-NNI round 5: LogLk = -28769.332 NNIs 0 max delta 0.00 Time 5.54
# Turning off heuristics for final round of ML NNIs (converged)
#       5.53 seconds: ML NNI round 6 of 17, 1 of 401 splits
#       5.78 seconds: ML NNI round 6 of 17, 101 of 401 splits, 2 changes (max delta 1.406)
#       6.06 seconds: ML NNI round 6 of 17, 201 of 401 splits, 2 changes (max delta 1.406)
#       6.32 seconds: ML NNI round 6 of 17, 301 of 401 splits, 2 changes (max delta 1.406)
# ML-NNI round 6: LogLk = -28728.683 NNIs 5 max delta 1.41 Time 6.61 (final)
#       6.60 seconds: ML Lengths 1 of 401 splits
#       6.71 seconds: ML Lengths 201 of 401 splits
#       6.82 seconds: ML Lengths 401 of 401 splits
# Optimize all lengths: LogLk = -28726.417 Time 6.83
#       7.14 seconds: ML split tests for    100 of    400 internal splits
#       7.46 seconds: ML split tests for    200 of    400 internal splits
#       7.77 seconds: ML split tests for    300 of    400 internal splits
# Total time: 8.09 seconds Unique: 403/416 Bad splits: 1/400 Worst delta-LogLk 1.018

# %% [markdown]
# ## ALPHA AND BETA DIVERSITY

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# # choose a round number in the 3rd quartile frequency per sample from the feature table visual summary
# # this step can take some time
# alpha_rarefaction_all = diversity.actions.alpha_rarefaction(
#     table = denoisetable_ba,
#     max_depth = 40000,
#     phylogeny = rooted_tree,
#     metrics = {'observed_features'},
#     metadata = sample_metadata,
#     steps = 1000
# )

# %%
# save alpha_rarefacion
# alpha_rarefaction_all.visualization.save('./results/alpha_rarefaction_40000.qzv')
qzv_file_alpha = q2.Visualization.load('./results/alpha_rarefaction_40000.qzv')

# %%
# sns.set()
# ax = dokdo.alpha_rarefaction_plot(qzv_file_alpha,
#                                   figsize=(9, 6),
#                                   metric='observed_features')
# ax.legend(ncol=5)
# plt.tight_layout()
# plt.savefig('./results/ba_alpha_rarefaction_plot.png')

# %%
qzv_file_alpha
# Out:
# <visualization: Visualization uuid: caaa43da-3fef-4226-9c91-3c3c5251f23d>

# %% [markdown]
# ### ALPHA DIVERSITY

# %%
# set sampling_depth based on alpha rarefacation curve
# normalization step
depth = 27291
action_results = diversity.actions.core_metrics_phylogenetic(
    table = denoisetable_ba,
    phylogeny = rooted_tree,
    sampling_depth = depth,
    metadata = sample_metadata
)
# Out:
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:1776: DataConversionWarning: Data was converted to boolean for metric jaccard
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:143: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0004879884568883438 and the largest is 1.4044564472643046.
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /tmp/qiime2-archive-ggfq33t0/ca0a3b2b-b47b-46ec-ae99-a1122c473993/data/feature-table.biom -t /tmp/qiime2-archive-0wcnitc_/40bfcd77-f546-4578-9eba-a37cb88d12c7/data/tree.nwk -o /tmp/q2-AlphaDiversityFormat-w94ipvq1
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-ggfq33t0/ca0a3b2b-b47b-46ec-ae99-a1122c473993/data/feature-table.biom -t /tmp/qiime2-archive-0wcnitc_/40bfcd77-f546-4578-9eba-a37cb88d12c7/data/tree.nwk -m unweighted -o /tmp/q2-LSMatFormat-wl1asfat
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-ggfq33t0/ca0a3b2b-b47b-46ec-ae99-a1122c473993/data/feature-table.biom -t /tmp/qiime2-archive-0wcnitc_/40bfcd77-f546-4578-9eba-a37cb88d12c7/data/tree.nwk -m weighted_unnormalized -o /tmp/q2-LSMatFormat-ui9g93yd
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:143: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0021291690622125665 and the largest is 0.16156041396261409.

# %%
action_results.bray_curtis_distance_matrix.view(view_type=DistanceMatrix)

# %%
action_results.jaccard_distance_matrix.view(view_type=DistanceMatrix)

# %%
action_results.jaccard_emperor
# Out:
# <visualization: Visualization uuid: d3475f2c-4732-4740-9b87-260db52dce79>

# %%
# alpha_rarefaction = diversity.visualizers.alpha_rarefaction(
#    table = denoisetable_ba,
#    phylogeny = rooted_tree,
#    max_depth = depth,
#    metadata = sample_metadata,
#    metrics = {'chao1', 'shannon', 'simpson', 'simpson_e', 'observed_features', 'fisher_alpha'},
#    steps =  100
# )

# # save alpha_rarefacion
# alpha_rarefaction.visualization.save('./results/alpha_rar.qzv')

# %%
# load alpha_rarefacion
alpha_rar = q2.Visualization.load('./results/alpha_rar.qzv')
alpha_rar
# Out:
# <visualization: Visualization uuid: 84638aec-9c7e-43b5-80a9-86b5f83eba09>

# %%
metrics = ['observed_features', 'fisher_alpha', 'chao1', 'shannon', 'simpson']

# alpha diversity metrics and significance

# init empty list
df_list = []
artifacts = {}

# loop over metrics
for metric in metrics:
    result = diversity.actions.alpha(
        table = action_results.rarefied_table,
        metric = metric
    )  # save to result
    artifact = result.alpha_diversity  # extract artifact
    artifacts[metric] = artifact
    df_list.append(artifact.view(view_type=q2.Metadata).to_dataframe())  # convert to DF and add to list
    
df = pd.concat(df_list, axis=1)  # merge list of dataframes, add each DF as new column (instead of new row (default))
df
# Out:
#            observed_features  fisher_alpha       chao1  shannon_entropy  \
# Sample ID
# P01A                    30.0      3.328980   37.500000         0.339169
# P03A                    81.0     10.272369   81.000000         4.180048
# P05A                    20.0      2.112734   20.750000         0.118682
# P07A                    52.0      6.197573   53.200000         2.276305
# P09A                    25.0      2.712516   25.666667         0.480064
# P11A                    91.0     11.739195   97.000000         5.274441
# P15A                    40.0      4.604325   43.111111         1.495196
# P17A                   119.0     15.988057  119.000000         2.745117
# P19A                    45.0      5.260529   49.090909         0.183254
# P20A                    80.0     10.127288   81.000000         1.880805
# P21A                    75.0      9.406438   81.875000         0.505759
# P22A                    99.0     12.932675  101.625000         3.962504
#
#             simpson
# Sample ID
# P01A       0.073405
# P03A       0.876491
# P05A       0.022411
# P07A       0.708194
# P09A       0.135138
# P11A       0.956614
# P15A       0.499034
# P17A       0.564873
# P19A       0.033859
# P20A       0.606854
# P21A       0.097439
# P22A       0.875174

# %%
ndf = df.merge(sample_metadata.to_dataframe(), left_index=True, right_index=True)
ndf["color"] = ndf.groupby("population").ngroup()
ndf.reset_index().plot.scatter("index", "observed_features", c="color", cmap=plt.cm.viridis)
# Out:
# <AxesSubplot:xlabel='index', ylabel='observed_features'>

# %%
ndf = df.merge(sample_metadata.to_dataframe(), left_index=True, right_index=True)

fig, axs = plt.subplots(ncols=2, figsize=(15, 5))

ax=axs[0]
ax.scatter(ndf.index, ndf.observed_features, color="C"+ndf.groupby("population").ngroup().astype(str))
ax.set_ylim([0, None])
ax.tick_params(axis='x', labelrotation=90)

ax=axs[1]
ax.scatter(ndf.index, ndf.shannon_entropy)
ax.set_ylim([0, None])
ax.tick_params(axis='x', labelrotation=90)


plt.tight_layout()

# %%
# visualisations of alpha diversity metrics
visualizations = {}

for key, value in artifacts.items():
    visualizations[key] = diversity.visualizers.alpha_group_significance(
        alpha_diversity = value,
        metadata = sample_metadata
    ).visualization

# %%
# # simpson viz
# visualizations['simpson']

# # fisher_alpha viz
# visualizations['fisher_alpha']

# # evenness_vector viz
# diversity.visualizers.alpha_group_significance(
#     alpha_diversity = action_results.evenness_vector,
#     metadata = sample_metadata
# ).visualization

# # evenness_vector viz
# diversity.visualizers.alpha_group_significance(
#     alpha_diversity = action_results.evenness_vector,
#     metadata = sample_metadata
# ).visualization

# # faith_pd viz
# diversity.visualizers.alpha_group_significance(
#     alpha_diversity = action_results.faith_pd_vector,
#     metadata = sample_metadata
# ).visualization

# %%
# observed_features viz
visualizations['observed_features']
# Out:
# <visualization: Visualization uuid: b75026f2-d924-4045-a066-182d6aa21b75>

# %%
# chao1 viz
visualizations['chao1']
# Out:
# <visualization: Visualization uuid: deb08f51-0bd4-438e-8dfb-0823b03cf588>

# %%
# shannon viz
visualizations['shannon']
# Out:
# <visualization: Visualization uuid: 57291408-9355-4abf-ba22-562f43894040>

# %% [markdown]
# ### BETA DIVERSITY

# %%
# make a subset, filter out dolenjska linija P05A
denoisetable_subset_population = q2.plugins.feature_table.methods.filter_samples(
    table = denoisetable_ba,
    metadata = sample_metadata,
    where = "[population] IN ('linija reke Ljubljanice', 'črna podvrsta')"
)

# %%
# make a subset, filter out P07A (2017), P11A (2018), P22A (2020); leave 2015, 2016, 2019
denoisetable_subset_year = q2.plugins.feature_table.methods.filter_samples(
    table = denoisetable_ba,
    metadata = sample_metadata,
    where = "[year] IN ('2015', '2016', '2019')"
)

# %%
# determine depth/s from alpha_rarefaction
# determine conditions from metadata column names
depth = 27291
condition = 'population'

core_metrics_results_subset_population = diversity.actions.core_metrics_phylogenetic(
    phylogeny = rooted_tree,
    table = denoisetable_subset_population.filtered_table,
    sampling_depth = depth,
    metadata = sample_metadata
)
# Out:
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:1776: DataConversionWarning: Data was converted to boolean for metric jaccard
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:143: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0005288617916681222 and the largest is 1.316236187611551.
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /tmp/qiime2-archive-71zljjxr/baee4569-162e-45e3-a3b4-0e44f22f0c95/data/feature-table.biom -t /tmp/qiime2-archive-0wcnitc_/40bfcd77-f546-4578-9eba-a37cb88d12c7/data/tree.nwk -o /tmp/q2-AlphaDiversityFormat-r3chsqu2
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-71zljjxr/baee4569-162e-45e3-a3b4-0e44f22f0c95/data/feature-table.biom -t /tmp/qiime2-archive-0wcnitc_/40bfcd77-f546-4578-9eba-a37cb88d12c7/data/tree.nwk -m unweighted -o /tmp/q2-LSMatFormat-i0tl4tfo
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-71zljjxr/baee4569-162e-45e3-a3b4-0e44f22f0c95/data/feature-table.biom -t /tmp/qiime2-archive-0wcnitc_/40bfcd77-f546-4578-9eba-a37cb88d12c7/data/tree.nwk -m weighted_unnormalized -o /tmp/q2-LSMatFormat-pzcmaqwt
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:143: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.002097676898051569 and the largest is 0.1529959461963278.

# %%
depth = 27291
condition = 'year'

core_metrics_results_subset_year = diversity.actions.core_metrics_phylogenetic(
    phylogeny = rooted_tree,
    table = denoisetable_subset_year.filtered_table,
    sampling_depth = depth,
    metadata = sample_metadata
)
# Out:
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:1776: DataConversionWarning: Data was converted to boolean for metric jaccard
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:143: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0002663142424203783 and the largest is 0.8351155898693327.
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /tmp/qiime2-archive-8995lp2d/0e39d278-73ff-4791-99a7-b67ae7bf9205/data/feature-table.biom -t /tmp/qiime2-archive-0wcnitc_/40bfcd77-f546-4578-9eba-a37cb88d12c7/data/tree.nwk -o /tmp/q2-AlphaDiversityFormat-xf9_4e7g
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-8995lp2d/0e39d278-73ff-4791-99a7-b67ae7bf9205/data/feature-table.biom -t /tmp/qiime2-archive-0wcnitc_/40bfcd77-f546-4578-9eba-a37cb88d12c7/data/tree.nwk -m unweighted -o /tmp/q2-LSMatFormat-ma03l3bc
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-8995lp2d/0e39d278-73ff-4791-99a7-b67ae7bf9205/data/feature-table.biom -t /tmp/qiime2-archive-0wcnitc_/40bfcd77-f546-4578-9eba-a37cb88d12c7/data/tree.nwk -m weighted_unnormalized -o /tmp/q2-LSMatFormat-45y5rqcu
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:143: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0004752140300719949 and the largest is 0.10309719350012778.

# %% [markdown]
# #### PERMANOVA

# %%
from qiime2.plugins.diversity.visualizers import beta_group_significance

permanova_population = beta_group_significance(
    distance_matrix = core_metrics_results_subset_population.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata.get_column('population'),
    method = "permanova",
    pairwise = True
)
permanova_population.visualization
# statistično značilno skupine enake - potrjena nulta hpoteza
# Out:
# <visualization: Visualization uuid: 8663a9bc-edfe-41fe-9278-7b2a53f33dcc>

# %%
# PERMANOVA year
from qiime2.plugins.diversity.visualizers import beta_group_significance

permanova_year = beta_group_significance(
    distance_matrix = core_metrics_results_subset_year.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata.get_column('year'),
    method = "permanova",
    pairwise = True
)
permanova_year.visualization

# ne moremo trdit da so si med leti enake
# Out:
# <visualization: Visualization uuid: 53b2076c-92a5-4f15-bbd8-037674e866dd>

# %% [markdown]
# #### PERMANOVA ADONIS
#
# Thefunction partitions sums of squares of a multivariate data set, and is
# directly analogous to MANOVA (multivariate analysis of variance). This
# action differs from beta_group_significance in that it accepts R formulae
# to perform multi-way ADONIS tests; beta_group_signficance only performs
# one-way tests.

# %%
adonis = q2.plugins.diversity.visualizers.adonis(
    distance_matrix = action_results.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata,
    formula =  "population+year"
)

adonis.visualization
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: run_adonis.R /tmp/tmp8xqwq9b_/dm.tsv /tmp/tmp8xqwq9b_/md.tsv population+year 999 1 /tmp/qiime2-temp-oljycs3n/adonis.tsv
#
# R version 4.1.3 (2022-03-10)
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.6-2
# 'adonis' will be deprecated: use 'adonis2' instead
# <visualization: Visualization uuid: b2ff982a-0a9a-4def-8295-f6b93fb78130>

# %%
adonis2 = q2.plugins.diversity.visualizers.adonis(
    distance_matrix = action_results.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata,
    formula =  "year+population"
)

adonis2.visualization
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: run_adonis.R /tmp/tmpuobe2ntj/dm.tsv /tmp/tmpuobe2ntj/md.tsv year+population 999 1 /tmp/qiime2-temp-d36hfcb0/adonis.tsv
#
# R version 4.1.3 (2022-03-10)
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.6-2
# 'adonis' will be deprecated: use 'adonis2' instead
# <visualization: Visualization uuid: 4555a680-618b-45c0-9b76-9c123142da68>

# %%
adonis = q2.plugins.diversity.visualizers.adonis(
    distance_matrix = action_results.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata,
    formula =  "population*year"
)

adonis.visualization
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: run_adonis.R /tmp/tmpxoan2rq1/dm.tsv /tmp/tmpxoan2rq1/md.tsv population*year 999 1 /tmp/qiime2-temp-m25m2ifk/adonis.tsv
#
# R version 4.1.3 (2022-03-10)
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.6-2
# 'adonis' will be deprecated: use 'adonis2' instead
# <visualization: Visualization uuid: 098d44c8-a18e-40fe-8ed0-9a7591e36c17>

# %%
adonis = q2.plugins.diversity.visualizers.adonis(
    distance_matrix = action_results.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata,
    formula =  "year*population"
)

adonis.visualization
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: run_adonis.R /tmp/tmprtx5svm1/dm.tsv /tmp/tmprtx5svm1/md.tsv year*population 999 1 /tmp/qiime2-temp-5xs5crd9/adonis.tsv
#
# R version 4.1.3 (2022-03-10)
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.6-2
# 'adonis' will be deprecated: use 'adonis2' instead
# <visualization: Visualization uuid: 93c8b451-1420-4a51-ac10-7d1799c891f4>

# %% [markdown]
# #### ANOSIM

# %%
anosim_population = beta_group_significance(
    distance_matrix = core_metrics_results_subset_population.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata.get_column('population'),
    method = "anosim",
    pairwise = True
)
anosim_population.visualization
# Out:
# <visualization: Visualization uuid: 720901b5-cc99-4f69-9212-f36b24f43711>

# %%
# anosim year

anosim_year = beta_group_significance(
    distance_matrix = core_metrics_results_subset_year.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata.get_column('year'),
    method = "anosim",
    pairwise = True
)
anosim_year.visualization
# Out:
# <visualization: Visualization uuid: 90fcfe06-be7b-4143-8f4e-0ebf6b67ee4e>
