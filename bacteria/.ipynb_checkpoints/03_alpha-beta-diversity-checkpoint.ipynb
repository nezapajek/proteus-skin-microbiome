# %% [markdown]
# # BACTERIA

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# %matplotlib inline

# %% [markdown]
# ### ALPHA & BETA DIVERSITY
# 1. make a MAFFT tree
# 2. alpha rarefaction
# 3. alpha diversity
# 4. beta diversity

# %%
#import packages
import os
import dokdo
import qiime2 as q2
import seaborn as sns
import pandas as pd
import plotnine as p9
import matplotlib.pyplot as plt
from qiime2.plugins import phylogeny
from qiime2.plugins import diversity
from skbio import DistanceMatrix
import qiime2.plugins.phylogeny.actions as phylogeny_actions

# %%
# define workdir
# %env WORKDIR /home/nezapa/qiime-thesis
WORKDIR = os.environ.get("WORKDIR")
# Out:
# env: WORKDIR=/home/nezapa/qiime-thesis

# %%
# import data
denoisetable_ba = q2.Artifact.load('./results/denoisetable_ba.qza')
rep_seqs_ba = q2.Artifact.load('./results/rep_seqs_ba.qza')
denoising_stats = q2.Artifact.load('./results/denoising_stats.qza')
sample_metadata = q2.Metadata.load('../00.sample-metadata.tsv')

# %% [markdown]
# ## TREE

# %%
action_results = phylogeny_actions.align_to_tree_mafft_fasttree(
    sequences=rep_seqs_ba,
)
aligned_rep_seqs = action_results.alignment
masked_aligned_rep_seqs = action_results.masked_alignment
unrooted_tree = action_results.tree
rooted_tree = action_results.rooted_tree
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: mafft --preservecase --inputorder --thread 1 /tmp/qiime2-archive-dycfghbo/c2be502a-68f0-4845-bf60-30311701ad19/data/dna-sequences.fasta
# inputfile = orig
# 416 x 260 - 260 d
# nthread = 1
# nthreadpair = 1
# nthreadtb = 1
# ppenalty_ex = 0
# stacksize: 8192 kb
# generating a scoring matrix for nucleotide (dist=200) ... done
# Gap Penalty = -1.53, +0.00, +0.00
#
#
#
# Making a distance matrix ..
#   401 / 416 (thread    0)
# done.
#
# Constructing a UPGMA tree (efffree=0) ...
#   410 / 416
# done.
#
# Progressive alignment 1/2...
# STEP    42 / 415 (thread    0)
# Reallocating..done. *alloclen = 1525
# STEP   415 / 415 (thread    0) h
# done.
#
# Making a distance matrix from msa..
#   400 / 416 (thread    0)
# done.
#
# Constructing a UPGMA tree (efffree=1) ...
#   410 / 416
# done.
#
# Progressive alignment 2/2...
# STEP   194 / 415 (thread    0)
# Reallocating..done. *alloclen = 1521
# STEP   415 / 415 (thread    0) h
# done.
#
# disttbfast (nuc) Version 7.505
# alg=A, model=DNA200 (2), 1.53 (4.59), -0.00 (-0.00), noshift, amax=0.0
# 1 thread(s)
#
#
# Strategy:
#  FFT-NS-2 (Fast but rough)
#  Progressive method (guide trees were built 2 times.)
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: FastTree -quote -nt /tmp/qiime2-archive-nfxesnev/28660d68-e4cf-4c2f-8b7b-5de7b01823ec/data/aligned-dna-sequences.fasta
# FastTree Version 2.1.10 Double precision (No SSE3)
# Alignment: /tmp/qiime2-archive-nfxesnev/28660d68-e4cf-4c2f-8b7b-5de7b01823ec/data/aligned-dna-sequences.fasta
# Nucleotide distances: Jukes-Cantor Joins: balanced Support: SH-like 1000
# Search: Normal +NNI +SPR (2 rounds range 10) +ML-NNI opt-each=1
# TopHits: 1.00*sqrtN close=default refresh=0.80
# ML Model: Jukes-Cantor, CAT approximation with 20 rate categories
#       0.14 seconds: Joined    100 of    399
#       0.28 seconds: Joined    300 of    399
# Initial topology in 0.34 seconds
# Refining topology: 35 rounds ME-NNIs, 2 rounds ME-SPRs, 17 rounds ML-NNIs
#       0.38 seconds: ME NNI round 2 of 35, 301 of 400 splits, 31 changes (max delta 0.181)
#       0.54 seconds: SPR round   1 of   2, 101 of 802 nodes
#       0.75 seconds: SPR round   1 of   2, 301 of 802 nodes
#       0.86 seconds: SPR round   1 of   2, 401 of 802 nodes
#       0.98 seconds: SPR round   1 of   2, 501 of 802 nodes
#       1.14 seconds: SPR round   1 of   2, 601 of 802 nodes
#       1.27 seconds: SPR round   1 of   2, 701 of 802 nodes
#       1.42 seconds: SPR round   1 of   2, 801 of 802 nodes
#       1.61 seconds: SPR round   2 of   2, 101 of 802 nodes
#       1.73 seconds: SPR round   2 of   2, 201 of 802 nodes
#       1.84 seconds: SPR round   2 of   2, 301 of 802 nodes
#       1.95 seconds: SPR round   2 of   2, 401 of 802 nodes
#       2.06 seconds: SPR round   2 of   2, 501 of 802 nodes
#       2.17 seconds: SPR round   2 of   2, 601 of 802 nodes
#       2.29 seconds: SPR round   2 of   2, 701 of 802 nodes
#       2.44 seconds: SPR round   2 of   2, 801 of 802 nodes
# Total branch-length 31.301 after 2.52 sec
#       2.58 seconds: ML Lengths 101 of 400 splits
#       2.72 seconds: ML Lengths 301 of 400 splits
#       3.06 seconds: ML NNI round 1 of 17, 101 of 400 splits, 18 changes (max delta 5.311)
#       3.32 seconds: ML NNI round 1 of 17, 201 of 400 splits, 38 changes (max delta 10.545)
#       3.60 seconds: ML NNI round 1 of 17, 301 of 400 splits, 63 changes (max delta 10.545)
# ML-NNI round 1: LogLk = -31770.340 NNIs 82 max delta 10.55 Time 3.87
#       3.87 seconds: Site likelihoods with rate category 1 of 20
#       3.97 seconds: Site likelihoods with rate category 13 of 20
# Switched to using 20 rate categories (CAT approximation)
# Rate categories were divided by 0.890 so that average rate = 1.0
# CAT-based log-likelihoods may not be comparable across runs
# Use -gamma for approximate but comparable Gamma(20) log-likelihoods
#       4.23 seconds: ML NNI round 2 of 17, 101 of 400 splits, 9 changes (max delta 4.096)
#       4.43 seconds: ML NNI round 2 of 17, 201 of 400 splits, 20 changes (max delta 4.220)
#       4.66 seconds: ML NNI round 2 of 17, 301 of 400 splits, 33 changes (max delta 4.220)
# ML-NNI round 2: LogLk = -28654.349 NNIs 45 max delta 9.63 Time 4.88
#       4.88 seconds: ML NNI round 3 of 17, 1 of 400 splits
#       5.05 seconds: ML NNI round 3 of 17, 101 of 400 splits, 3 changes (max delta 1.598)
#       5.25 seconds: ML NNI round 3 of 17, 201 of 400 splits, 13 changes (max delta 3.473)
# ML-NNI round 3: LogLk = -28614.183 NNIs 22 max delta 4.55 Time 5.42
#       5.42 seconds: ML NNI round 4 of 17, 1 of 400 splits
#       5.58 seconds: ML NNI round 4 of 17, 101 of 400 splits, 8 changes (max delta 5.365)
# ML-NNI round 4: LogLk = -28602.745 NNIs 9 max delta 5.37 Time 5.72
#       5.71 seconds: ML NNI round 5 of 17, 1 of 400 splits
# ML-NNI round 5: LogLk = -28600.914 NNIs 3 max delta 0.40 Time 5.88
#       5.87 seconds: ML NNI round 6 of 17, 1 of 400 splits
# ML-NNI round 6: LogLk = -28600.835 NNIs 0 max delta 0.00 Time 5.95
# Turning off heuristics for final round of ML NNIs (converged)
#       6.19 seconds: ML NNI round 7 of 17, 101 of 400 splits, 0 changes
#       6.47 seconds: ML NNI round 7 of 17, 201 of 400 splits, 0 changes
#       6.74 seconds: ML NNI round 7 of 17, 301 of 400 splits, 0 changes
# ML-NNI round 7: LogLk = -28582.954 NNIs 0 max delta 0.00 Time 7.03 (final)
#       7.02 seconds: ML Lengths 1 of 400 splits
#       7.13 seconds: ML Lengths 201 of 400 splits
# Optimize all lengths: LogLk = -28582.577 Time 7.25
#       7.56 seconds: ML split tests for    100 of    399 internal splits
#       7.87 seconds: ML split tests for    200 of    399 internal splits
#       8.19 seconds: ML split tests for    300 of    399 internal splits
# Total time: 8.51 seconds Unique: 402/416 Bad splits: 0/399

# %% [markdown]
# ## ALPHA AND BETA DIVERSITY

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# # choose a round number in the 3rd quartile frequency per sample from the feature table visual summary
# # this step can take some time
# alpha_rarefaction_all = diversity.actions.alpha_rarefaction(
#     table = denoisetable_ba,
#     max_depth = 40000,
#     phylogeny = rooted_tree,
#     metrics = {'observed_features'},
#     metadata = sample_metadata,
#     steps = 1000
# )

# %%
# save alpha_rarefacion
# alpha_rarefaction_all.visualization.save('./results/alpha_rarefaction_40000.qzv')
qzv_file_alpha = q2.Visualization.load('./results/alpha_rarefaction_40000.qzv')

# %%
# sns.set()
# ax = dokdo.alpha_rarefaction_plot(qzv_file_alpha,
#                                   figsize=(9, 6),
#                                   metric='observed_features')
# ax.legend(ncol=5)
# plt.tight_layout()
# plt.savefig('./results/ba_alpha_rarefaction_plot.png')

# %%
qzv_file_alpha
# Out:
# <visualization: Visualization uuid: caaa43da-3fef-4226-9c91-3c3c5251f23d>

# %% [markdown]
# ### ALPHA DIVERSITY

# %%
# set sampling_depth based on alpha rarefacation curve
# normalization step
depth = 27291
action_results = diversity.actions.core_metrics_phylogenetic(
    table = denoisetable_ba,
    phylogeny = rooted_tree,
    sampling_depth = depth,
    metadata = sample_metadata
)
# Out:
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:1776: DataConversionWarning: Data was converted to boolean for metric jaccard
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:143: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0005486469859843696 and the largest is 1.40336802895963.
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /tmp/qiime2-archive-96u2yvvi/8110393f-a576-4843-88a0-eb58c52d1f54/data/feature-table.biom -t /tmp/qiime2-archive-gj6ay4mr/0da14f7a-bd0b-4501-b592-b99e72d4dc9f/data/tree.nwk -o /tmp/q2-AlphaDiversityFormat-evf3v0w5
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-96u2yvvi/8110393f-a576-4843-88a0-eb58c52d1f54/data/feature-table.biom -t /tmp/qiime2-archive-gj6ay4mr/0da14f7a-bd0b-4501-b592-b99e72d4dc9f/data/tree.nwk -m unweighted -o /tmp/q2-LSMatFormat-8s1uz3nl
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-96u2yvvi/8110393f-a576-4843-88a0-eb58c52d1f54/data/feature-table.biom -t /tmp/qiime2-archive-gj6ay4mr/0da14f7a-bd0b-4501-b592-b99e72d4dc9f/data/tree.nwk -m weighted_unnormalized -o /tmp/q2-LSMatFormat-j7nqwb3l
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:143: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.002734581194202541 and the largest is 0.15663363925720952.

# %%
action_results.bray_curtis_distance_matrix.view(view_type=DistanceMatrix)

# %%
action_results.jaccard_distance_matrix.view(view_type=DistanceMatrix)

# %%
action_results.jaccard_emperor
# Out:
# <visualization: Visualization uuid: e76d73ff-eece-409e-9238-07b618151515>

# %%
# alpha_rarefaction = diversity.visualizers.alpha_rarefaction(
#    table = denoisetable_ba,
#    phylogeny = rooted_tree,
#    max_depth = depth,
#    metadata = sample_metadata,
#    metrics = {'chao1', 'shannon', 'simpson', 'simpson_e', 'observed_features', 'fisher_alpha'},
#    steps =  100
# )

# # save alpha_rarefacion
# alpha_rarefaction.visualization.save('./results/alpha_rar.qzv')

# %%
# load alpha_rarefacion
alpha_rar = q2.Visualization.load('./results/alpha_rar.qzv')
alpha_rar
# Out:
# <visualization: Visualization uuid: 84638aec-9c7e-43b5-80a9-86b5f83eba09>

# %%
metrics = ['observed_features', 'fisher_alpha', 'chao1', 'shannon', 'simpson']

# alpha diversity metrics and significance

# init empty list
df_list = []
artifacts = {}

# loop over metrics
for metric in metrics:
    result = diversity.actions.alpha(
        table = action_results.rarefied_table,
        metric = metric
    )  # save to result
    artifact = result.alpha_diversity  # extract artifact
    artifacts[metric] = artifact
    df_list.append(artifact.view(view_type=q2.Metadata).to_dataframe())  # convert to DF and add to list
    
df = pd.concat(df_list, axis=1)  # merge list of dataframes, add each DF as new column (instead of new row (default))
df
# Out:
#            observed_features  fisher_alpha       chao1  shannon_entropy  \
# Sample ID
# P01A                    31.0      3.454085   33.500000         0.335250
# P03A                    81.0     10.272369   82.000000         4.173578
# P05A                    19.0      1.995016   24.000000         0.117071
# P07A                    50.0      5.927765   51.000000         2.282146
# P09A                    26.0      2.834550   26.909091         0.479569
# P11A                    92.0     11.887432   95.000000         5.276303
# P15A                    40.0      4.604325   43.111111         1.495283
# P17A                   120.0     16.143365  120.500000         2.744986
# P19A                    45.0      5.260529   52.333333         0.185345
# P20A                    79.0      9.982507   79.000000         1.890736
# P21A                    74.0      9.263197   87.200000         0.512879
# P22A                    97.0     12.632698  104.000000         3.967826
#
#             simpson
# Sample ID
# P01A       0.072290
# P03A       0.876061
# P05A       0.022622
# P07A       0.710059
# P09A       0.135173
# P11A       0.956564
# P15A       0.499206
# P17A       0.564080
# P19A       0.034713
# P20A       0.607467
# P21A       0.099244
# P22A       0.876142

# %%
ndf = df.merge(sample_metadata.to_dataframe(), left_index=True, right_index=True)
ndf["color"] = ndf.groupby("population").ngroup()
ndf.reset_index().plot.scatter("index", "observed_features", c="color", cmap=plt.cm.viridis)
# Out:
# <AxesSubplot:xlabel='index', ylabel='observed_features'>

# %%
ndf.head()
# Out:
#       observed_features  fisher_alpha      chao1  shannon_entropy   simpson  \
# P01A               31.0      3.454085  33.500000         0.335250  0.072290
# P03A               81.0     10.272369  82.000000         4.173578  0.876061
# P05A               19.0      1.995016  24.000000         0.117071  0.022622
# P07A               50.0      5.927765  51.000000         2.282146  0.710059
# P09A               26.0      2.834550  26.909091         0.479569  0.135173
#
#      sample        location       origin  year parkelj specimen  \
# P01A   P01A  Planinska_jama    Paa200_t0  2015      no   Paa200
# P03A   P03A  Planinska_jama    Paa201_t0  2015      no   Paa201
# P05A   P05A           Stobe  Paa204_t10d  2016      no   Paa204
# P07A   P07A  Planinska_jama    Paa209_t0  2017      no   Paa209
# P09A   P09A  Planinska_jama    Paa210_t0  2019      no   Paa210
#
#                    population  color
# P01A  linija reke Ljubljanice      1
# P03A  linija reke Ljubljanice      1
# P05A         dolenjska linija      0
# P07A  linija reke Ljubljanice      1
# P09A  linija reke Ljubljanice      1

# %%
col = 'observed_features'
meta_cols = ['year', 'population']
df1 = ndf[meta_cols + [col]].rename(columns={col: 'value'}).eval('type=@col')

col = 'chao1'
df2 = ndf[meta_cols + [col]].rename(columns={col: 'value'}).eval('type=@col')

df = pd.concat([df1, df2])
df
# Out:
#       year               population       value               type
# P01A  2015  linija reke Ljubljanice   31.000000  observed_features
# P03A  2015  linija reke Ljubljanice   81.000000  observed_features
# P05A  2016         dolenjska linija   19.000000  observed_features
# P07A  2017  linija reke Ljubljanice   50.000000  observed_features
# P09A  2019  linija reke Ljubljanice   26.000000  observed_features
# P11A  2018  linija reke Ljubljanice   92.000000  observed_features
# P15A  2019  linija reke Ljubljanice   40.000000  observed_features
# P17A  2019  linija reke Ljubljanice  120.000000  observed_features
# P19A  2016            črna podvrsta   45.000000  observed_features
# P20A  2016            črna podvrsta   79.000000  observed_features
# P21A  2015            črna podvrsta   74.000000  observed_features
# P22A  2020            črna podvrsta   97.000000  observed_features
# P01A  2015  linija reke Ljubljanice   33.500000              chao1
# P03A  2015  linija reke Ljubljanice   82.000000              chao1
# P05A  2016         dolenjska linija   24.000000              chao1
# P07A  2017  linija reke Ljubljanice   51.000000              chao1
# P09A  2019  linija reke Ljubljanice   26.909091              chao1
# P11A  2018  linija reke Ljubljanice   95.000000              chao1
# P15A  2019  linija reke Ljubljanice   43.111111              chao1
# P17A  2019  linija reke Ljubljanice  120.500000              chao1
# P19A  2016            črna podvrsta   52.333333              chao1
# P20A  2016            črna podvrsta   79.000000              chao1
# P21A  2015            črna podvrsta   87.200000              chao1
# P22A  2020            črna podvrsta  104.000000              chao1

# %%
from plotnine import *
from plotnine.data import *

(
    ggplot(df, aes(x=df.index, y='value', shape='year', color='population', alpha='type'))
    + geom_point(size=4)
    + labs(x='Sample ID', y='Value')
    + scale_color_manual(['C0', 'C1', 'C2'])
    + scale_alpha_manual([0.3, 1.0])
)
# Out:
# <ggplot: (8779290198492)>

# %%
ndf = df.merge(sample_metadata.to_dataframe(), left_index=True, right_index=True)

fig, axs = plt.subplots(ncols=2, figsize=(15, 5))

ax=axs[0]
ax.scatter(ndf.index, ndf.observed_features, color="C"+ndf.groupby("population").ngroup().astype(str))
ax.set_ylim([0, None])
ax.tick_params(axis='x', labelrotation=90)

ax=axs[1]
ax.scatter(ndf.index, ndf.shannon_entropy)
ax.set_ylim([0, None])
ax.tick_params(axis='x', labelrotation=90)


plt.tight_layout()

# %%
# visualisations of alpha diversity metrics
visualizations = {}

for key, value in artifacts.items():
    visualizations[key] = diversity.visualizers.alpha_group_significance(
        alpha_diversity = value,
        metadata = sample_metadata
    ).visualization

# %%
# # simpson viz
# visualizations['simpson']

# # fisher_alpha viz
# visualizations['fisher_alpha']

# # evenness_vector viz
# diversity.visualizers.alpha_group_significance(
#     alpha_diversity = action_results.evenness_vector,
#     metadata = sample_metadata
# ).visualization

# # evenness_vector viz
# diversity.visualizers.alpha_group_significance(
#     alpha_diversity = action_results.evenness_vector,
#     metadata = sample_metadata
# ).visualization

# # faith_pd viz
# diversity.visualizers.alpha_group_significance(
#     alpha_diversity = action_results.faith_pd_vector,
#     metadata = sample_metadata
# ).visualization

# %%
# observed_features viz
visualizations['observed_features']
# Out:
# <visualization: Visualization uuid: e314589d-4675-4da2-8f12-8f746ed275df>

# %%
# chao1 viz
visualizations['chao1']
# Out:
# <visualization: Visualization uuid: f1a3f26a-f13f-47be-8b66-829dead2a400>

# %%
# shannon viz
visualizations['shannon']
# Out:
# <visualization: Visualization uuid: b5cd5e76-ee35-44a9-8194-e90f56db5e20>

# %% [markdown]
# ### BETA DIVERSITY

# %%
# make a subset, filter out dolenjska linija P05A
denoisetable_subset_population = q2.plugins.feature_table.methods.filter_samples(
    table = denoisetable_ba,
    metadata = sample_metadata,
    where = "[population] IN ('linija reke Ljubljanice', 'črna podvrsta')"
)

# %%
# make a subset, filter out P07A (2017), P11A (2018), P22A (2020); leave 2015, 2016, 2019
denoisetable_subset_year = q2.plugins.feature_table.methods.filter_samples(
    table = denoisetable_ba,
    metadata = sample_metadata,
    where = "[year] IN ('2015', '2016', '2019')"
)

# %%
# determine depth/s from alpha_rarefaction
# determine conditions from metadata column names
depth = 27291
condition = 'population'

core_metrics_results_subset_population = diversity.actions.core_metrics_phylogenetic(
    phylogeny = rooted_tree,
    table = denoisetable_subset_population.filtered_table,
    sampling_depth = depth,
    metadata = sample_metadata
)
# Out:
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:1776: DataConversionWarning: Data was converted to boolean for metric jaccard
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:143: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0005228055863829378 and the largest is 1.3173901024724988.
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /tmp/qiime2-archive-947whbqq/76bc3f93-8fd5-4288-8a76-d6ca5e77313c/data/feature-table.biom -t /tmp/qiime2-archive-_w4bx_21/ac5a49dd-e14f-45eb-8286-0161aaf3569d/data/tree.nwk -o /tmp/q2-AlphaDiversityFormat-2sw2z1q7
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-947whbqq/76bc3f93-8fd5-4288-8a76-d6ca5e77313c/data/feature-table.biom -t /tmp/qiime2-archive-_w4bx_21/ac5a49dd-e14f-45eb-8286-0161aaf3569d/data/tree.nwk -m unweighted -o /tmp/q2-LSMatFormat-mjxhyfd2
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-947whbqq/76bc3f93-8fd5-4288-8a76-d6ca5e77313c/data/feature-table.biom -t /tmp/qiime2-archive-_w4bx_21/ac5a49dd-e14f-45eb-8286-0161aaf3569d/data/tree.nwk -m weighted_unnormalized -o /tmp/q2-LSMatFormat-s8qp504s
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:143: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0024908035164368145 and the largest is 0.1538297764836102.

# %%
depth = 27291
condition = 'year'

core_metrics_results_subset_year = diversity.actions.core_metrics_phylogenetic(
    phylogeny = rooted_tree,
    table = denoisetable_subset_year.filtered_table,
    sampling_depth = depth,
    metadata = sample_metadata
)
# Out:
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:1776: DataConversionWarning: Data was converted to boolean for metric jaccard
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:143: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0002678349084564146 and the largest is 0.8352453933457579.
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /tmp/qiime2-archive-j17uce41/90f6237b-ec8c-4f7b-a2ed-b3d2e72b3388/data/feature-table.biom -t /tmp/qiime2-archive-_w4bx_21/ac5a49dd-e14f-45eb-8286-0161aaf3569d/data/tree.nwk -o /tmp/q2-AlphaDiversityFormat-4j_vsm2b
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-j17uce41/90f6237b-ec8c-4f7b-a2ed-b3d2e72b3388/data/feature-table.biom -t /tmp/qiime2-archive-_w4bx_21/ac5a49dd-e14f-45eb-8286-0161aaf3569d/data/tree.nwk -m unweighted -o /tmp/q2-LSMatFormat-d2qbpm99
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-j17uce41/90f6237b-ec8c-4f7b-a2ed-b3d2e72b3388/data/feature-table.biom -t /tmp/qiime2-archive-_w4bx_21/ac5a49dd-e14f-45eb-8286-0161aaf3569d/data/tree.nwk -m weighted_unnormalized -o /tmp/q2-LSMatFormat-4dstb2qr
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:143: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0006558122330023126 and the largest is 0.10817189032556486.

# %% [markdown]
# #### PERMANOVA

# %%
from qiime2.plugins.diversity.visualizers import beta_group_significance

permanova_population = beta_group_significance(
    distance_matrix = core_metrics_results_subset_population.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata.get_column('population'),
    method = "permanova",
    pairwise = True
)
permanova_population.visualization
# statistično značilno skupine enake - potrjena nulta hpoteza
# Out:
# <visualization: Visualization uuid: 1ad8ee0b-cbd2-45dd-9abf-c3b639cb3fcf>

# %%
# PERMANOVA year
from qiime2.plugins.diversity.visualizers import beta_group_significance

permanova_year = beta_group_significance(
    distance_matrix = core_metrics_results_subset_year.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata.get_column('year'),
    method = "permanova",
    pairwise = True
)
permanova_year.visualization

# ne moremo trdit da so si med leti enake
# Out:
# <visualization: Visualization uuid: 4bae5552-a12c-4c5f-aed5-0c0cf11ea3c3>

# %% [markdown]
# #### PERMANOVA ADONIS
#
# Thefunction partitions sums of squares of a multivariate data set, and is
# directly analogous to MANOVA (multivariate analysis of variance). This
# action differs from beta_group_significance in that it accepts R formulae
# to perform multi-way ADONIS tests; beta_group_signficance only performs
# one-way tests.

# %%
adonis = q2.plugins.diversity.visualizers.adonis(
    distance_matrix = action_results.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata,
    formula =  "population+year"
)

adonis.visualization
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: run_adonis.R /tmp/tmpz_y43h32/dm.tsv /tmp/tmpz_y43h32/md.tsv population+year 999 1 /tmp/qiime2-temp-ngldtey5/adonis.tsv
#
# R version 4.1.3 (2022-03-10)
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.6-2
# 'adonis' will be deprecated: use 'adonis2' instead
# <visualization: Visualization uuid: 9cb9ab36-8d74-4650-b775-10a1df980781>

# %%
adonis2 = q2.plugins.diversity.visualizers.adonis(
    distance_matrix = action_results.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata,
    formula =  "year+population"
)

adonis2.visualization
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: run_adonis.R /tmp/tmpxj_r3i8s/dm.tsv /tmp/tmpxj_r3i8s/md.tsv year+population 999 1 /tmp/qiime2-temp-m13zzvno/adonis.tsv
#
# R version 4.1.3 (2022-03-10)
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.6-2
# 'adonis' will be deprecated: use 'adonis2' instead
# <visualization: Visualization uuid: e06b4aa7-f881-4cf7-971d-1739a47fbf36>

# %%
adonis = q2.plugins.diversity.visualizers.adonis(
    distance_matrix = action_results.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata,
    formula =  "population*year"
)

adonis.visualization
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: run_adonis.R /tmp/tmpjeh1zgrh/dm.tsv /tmp/tmpjeh1zgrh/md.tsv population*year 999 1 /tmp/qiime2-temp-k591j__h/adonis.tsv
#
# R version 4.1.3 (2022-03-10)
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.6-2
# 'adonis' will be deprecated: use 'adonis2' instead
# <visualization: Visualization uuid: 0c334017-f555-4d01-8a5a-f6ebb4ad6062>

# %%
adonis = q2.plugins.diversity.visualizers.adonis(
    distance_matrix = action_results.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata,
    formula =  "year*population"
)

adonis.visualization
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: run_adonis.R /tmp/tmppeqm89yb/dm.tsv /tmp/tmppeqm89yb/md.tsv year*population 999 1 /tmp/qiime2-temp-spord4t7/adonis.tsv
#
# R version 4.1.3 (2022-03-10)
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.6-2
# 'adonis' will be deprecated: use 'adonis2' instead
# <visualization: Visualization uuid: 65d3a151-943a-4d14-a228-1b9d90e5e1c4>

# %% [markdown]
# #### ANOSIM

# %%
anosim_population = beta_group_significance(
    distance_matrix = core_metrics_results_subset_population.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata.get_column('population'),
    method = "anosim",
    pairwise = True
)
anosim_population.visualization
# Out:
# <visualization: Visualization uuid: 821c2316-738d-41c0-b95d-c1a9c5b299f1>

# %%
# anosim year

anosim_year = beta_group_significance(
    distance_matrix = core_metrics_results_subset_year.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata.get_column('year'),
    method = "anosim",
    pairwise = True
)
anosim_year.visualization
# Out:
# <visualization: Visualization uuid: 3ca9f411-b464-4c48-8aa7-ca4f13b9d6ca>
