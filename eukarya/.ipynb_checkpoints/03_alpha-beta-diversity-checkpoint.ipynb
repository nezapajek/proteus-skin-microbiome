# %% [markdown]
# # EUKARYA

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# %matplotlib inline

# %% [markdown]
# ### ALPHA & BETA DIVERSITY
# 1. make a MAFFT tree
# 2. alpha rarefaction
# 3. alpha diversity
# 4. beta diversity

# %%
#import packages
import os
import dokdo
import qiime2 as q2
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from qiime2.plugins import phylogeny
from qiime2.plugins import diversity
from skbio import DistanceMatrix
import qiime2.plugins.phylogeny.actions as phylogeny_actions

# %%
# define workdir
# %env WORKDIR /home/nezapa/qiime-thesis
WORKDIR = os.environ.get("WORKDIR")
# Out:
# env: WORKDIR=/home/nezapa/qiime-thesis

# %%
# import data
denoisetable_eu = q2.Artifact.load('./results/denoisetable_eu.qza')
rep_seqs_eu = q2.Artifact.load('./results/rep_seqs_eu.qza')
denoising_stats = q2.Artifact.load('./results/denoising_stats.qza')
sample_metadata = q2.Metadata.load('../00.sample-metadata.tsv')

# %% [markdown]
# ## TREE

# %%
action_results = phylogeny_actions.align_to_tree_mafft_fasttree(
    sequences=rep_seqs_eu,
)
aligned_rep_seqs = action_results.alignment
masked_aligned_rep_seqs = action_results.masked_alignment
unrooted_tree = action_results.tree
rooted_tree = action_results.rooted_tree
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: mafft --preservecase --inputorder --thread 1 /tmp/qiime2-archive-vu3lgpgh/61935e82-aac1-47d3-99d0-c85985ce844f/data/dna-sequences.fasta
# inputfile = orig
# 578 x 260 - 260 d
# nthread = 1
# nthreadpair = 1
# nthreadtb = 1
# ppenalty_ex = 0
# stacksize: 8192 kb
# generating a scoring matrix for nucleotide (dist=200) ... done
# Gap Penalty = -1.53, +0.00, +0.00
#
#
#
# Making a distance matrix ..
#   501 / 578 (thread    0)
# done.
#
# Constructing a UPGMA tree (efffree=0) ...
#   570 / 578
# done.
#
# Progressive alignment 1/2...
# STEP    64 / 577 (thread    0)
# Reallocating..done. *alloclen = 1521
# STEP   501 / 577 (thread    0) h
# done.
#
# Making a distance matrix from msa..
#   500 / 578 (thread    0)
# done.
#
# Constructing a UPGMA tree (efffree=1) ...
#   570 / 578
# done.
#
# Progressive alignment 2/2...
# STEP   469 / 577 (thread    0) h
# Reallocating..done. *alloclen = 1521
# STEP   501 / 577 (thread    0) h
# done.
#
# disttbfast (nuc) Version 7.505
# alg=A, model=DNA200 (2), 1.53 (4.59), -0.00 (-0.00), noshift, amax=0.0
# 1 thread(s)
#
#
# Strategy:
#  FFT-NS-2 (Fast but rough)
#  Progressive method (guide trees were built 2 times.)
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: FastTree -quote -nt /tmp/qiime2-archive-6kea_e3q/9b211771-3c7e-404f-b971-80b3cfefee8b/data/aligned-dna-sequences.fasta
# FastTree Version 2.1.10 Double precision (No SSE3)
# Alignment: /tmp/qiime2-archive-6kea_e3q/9b211771-3c7e-404f-b971-80b3cfefee8b/data/aligned-dna-sequences.fasta
# Nucleotide distances: Jukes-Cantor Joins: balanced Support: SH-like 1000
# Search: Normal +NNI +SPR (2 rounds range 10) +ML-NNI opt-each=1
# TopHits: 1.00*sqrtN close=default refresh=0.80
# ML Model: Jukes-Cantor, CAT approximation with 20 rate categories
#       0.11 seconds: Checking top hits for      1 of    578 seqs
#       0.22 seconds: Joined    200 of    575
#       0.35 seconds: Joined    400 of    575
# Initial topology in 0.45 seconds
# Refining topology: 37 rounds ME-NNIs, 2 rounds ME-SPRs, 18 rounds ML-NNIs
#       0.45 seconds: ME NNI round 1 of 37, 101 of 576 splits, 20 changes (max delta 0.001)
#       0.62 seconds: SPR round   1 of   2, 101 of 1154 nodes
#       0.80 seconds: SPR round   1 of   2, 301 of 1154 nodes
#       0.95 seconds: SPR round   1 of   2, 501 of 1154 nodes
#       1.14 seconds: SPR round   1 of   2, 701 of 1154 nodes
#       1.30 seconds: SPR round   1 of   2, 901 of 1154 nodes
#       1.46 seconds: SPR round   1 of   2, 1101 of 1154 nodes
#       1.56 seconds: ME NNI round 19 of 37, 1 of 576 splits
#       1.73 seconds: SPR round   2 of   2, 201 of 1154 nodes
#       1.88 seconds: SPR round   2 of   2, 401 of 1154 nodes
#       2.07 seconds: SPR round   2 of   2, 601 of 1154 nodes
#       2.21 seconds: SPR round   2 of   2, 801 of 1154 nodes
#       2.31 seconds: SPR round   2 of   2, 901 of 1154 nodes
#       2.48 seconds: SPR round   2 of   2, 1101 of 1154 nodes
# Total branch-length 12.317 after 2.61 sec
#       2.61 seconds: ML Lengths 1 of 576 splits
#       2.75 seconds: ML Lengths 301 of 576 splits
#       2.88 seconds: ML NNI round 1 of 18, 1 of 576 splits
#       3.03 seconds: ML NNI round 1 of 18, 101 of 576 splits, 31 changes (max delta 2.841)
#       3.19 seconds: ML NNI round 1 of 18, 201 of 576 splits, 68 changes (max delta 6.193)
#       3.34 seconds: ML NNI round 1 of 18, 301 of 576 splits, 106 changes (max delta 6.193)
#       3.48 seconds: ML NNI round 1 of 18, 401 of 576 splits, 143 changes (max delta 6.193)
#       3.63 seconds: ML NNI round 1 of 18, 501 of 576 splits, 180 changes (max delta 6.193)
# ML-NNI round 1: LogLk = -16116.194 NNIs 217 max delta 6.19 Time 3.76
#       3.76 seconds: Site likelihoods with rate category 1 of 20
#       3.87 seconds: Site likelihoods with rate category 11 of 20
# Switched to using 20 rate categories (CAT approximation)
# Rate categories were divided by 0.828 so that average rate = 1.0
# CAT-based log-likelihoods may not be comparable across runs
# Use -gamma for approximate but comparable Gamma(20) log-likelihoods
#       3.98 seconds: ML NNI round 2 of 18, 1 of 576 splits
#       4.10 seconds: ML NNI round 2 of 18, 101 of 576 splits, 13 changes (max delta 0.000)
#       4.24 seconds: ML NNI round 2 of 18, 201 of 576 splits, 35 changes (max delta 0.222)
#       4.37 seconds: ML NNI round 2 of 18, 301 of 576 splits, 58 changes (max delta 0.222)
#       4.50 seconds: ML NNI round 2 of 18, 401 of 576 splits, 77 changes (max delta 4.889)
#       4.63 seconds: ML NNI round 2 of 18, 501 of 576 splits, 101 changes (max delta 4.889)
# ML-NNI round 2: LogLk = -15530.289 NNIs 115 max delta 4.89 Time 4.73
#       4.73 seconds: ML NNI round 3 of 18, 1 of 576 splits
#       4.84 seconds: ML NNI round 3 of 18, 101 of 576 splits, 8 changes (max delta 0.000)
#       4.96 seconds: ML NNI round 3 of 18, 201 of 576 splits, 23 changes (max delta 5.283)
#       5.08 seconds: ML NNI round 3 of 18, 301 of 576 splits, 31 changes (max delta 5.283)
#       5.18 seconds: ML NNI round 3 of 18, 401 of 576 splits, 43 changes (max delta 5.283)
# ML-NNI round 3: LogLk = -15522.501 NNIs 60 max delta 5.28 Time 5.31
#       5.30 seconds: ML NNI round 4 of 18, 1 of 576 splits
#       5.40 seconds: ML NNI round 4 of 18, 101 of 576 splits, 5 changes (max delta 0.000)
#       5.62 seconds: ML NNI round 4 of 18, 301 of 576 splits, 24 changes (max delta 0.000)
# ML-NNI round 4: LogLk = -15522.296 NNIs 37 max delta 0.00 Time 5.70
# Turning off heuristics for final round of ML NNIs (converged)
#       5.83 seconds: ML NNI round 5 of 18, 101 of 576 splits, 3 changes (max delta 0.000)
#       5.96 seconds: ML NNI round 5 of 18, 201 of 576 splits, 14 changes (max delta 0.000)
#       6.10 seconds: ML NNI round 5 of 18, 301 of 576 splits, 20 changes (max delta 0.000)
#       6.26 seconds: ML NNI round 5 of 18, 401 of 576 splits, 23 changes (max delta 0.000)
#       6.39 seconds: ML NNI round 5 of 18, 501 of 576 splits, 25 changes (max delta 0.000)
# ML-NNI round 5: LogLk = -15520.756 NNIs 30 max delta 0.00 Time 6.50 (final)
#       6.50 seconds: ML Lengths 1 of 576 splits
#       6.61 seconds: ML Lengths 301 of 576 splits
# Optimize all lengths: LogLk = -15520.741 Time 6.71
#       6.91 seconds: ML split tests for    100 of    575 internal splits
#       7.11 seconds: ML split tests for    200 of    575 internal splits
#       7.30 seconds: ML split tests for    300 of    575 internal splits
#       7.50 seconds: ML split tests for    400 of    575 internal splits
#       7.69 seconds: ML split tests for    500 of    575 internal splits
# Total time: 7.84 seconds Unique: 578/578 Bad splits: 1/575 Worst delta-LogLk 0.116

# %% [markdown]
# ## ALPHA AND BETA DIVERSITY

# %%
from qiime2.plugins import feature_table

# summarise and visualise
feature_table.visualizers.summarize(
    table = denoisetable_eu,
    sample_metadata = sample_metadata
).visualization
# Out:
# <visualization: Visualization uuid: b7667190-6de2-4f93-8516-77168c7e07b9>

# %%
# # choose a round number in the 3rd quartile frequency per sample from the feature table visual summary
# # this step can take some time
# alpha_rarefaction_all = diversity.actions.alpha_rarefaction(
#     table = denoisetable_eu,
#     max_depth = 30000,
#     phylogeny = rooted_tree,
#     metrics = {'observed_features'},
#     metadata = sample_metadata,
#     steps = 1000
# )

# %%
# save alpha_rarefacion
# alpha_rarefaction_all.visualization.save('./results/alpha_rarefaction_30000.qzv')
qzv_file_alpha = q2.Visualization.load('./results/alpha_rarefaction_30000.qzv')

# %%
# sns.set()
# ax = dokdo.alpha_rarefaction_plot(qzv_file_alpha,
#                                   figsize=(9, 6),
#                                   metric='observed_features')
# ax.legend(ncol=5)
# plt.tight_layout()
# plt.savefig('./results/eu_alpha_rarefaction_plot.png')

# %% [markdown]
# ### ALPHA DIVERSITY

# %%
# set sampling_depth based on alpha rarefacation curve
depth = 14448
action_results = diversity.actions.core_metrics_phylogenetic(
    table = denoisetable_eu,
    phylogeny = rooted_tree,
    sampling_depth = depth,
    metadata = sample_metadata
)
# Out:
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:1776: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /tmp/qiime2-archive-fovn_h67/d15e4e70-d753-484e-a6ce-6d127f8797ea/data/feature-table.biom -t /tmp/qiime2-archive-clbh86dl/a6875c1e-e1fb-438b-8a1a-780f1183e637/data/tree.nwk -o /tmp/q2-AlphaDiversityFormat-y9nsdrr6
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-fovn_h67/d15e4e70-d753-484e-a6ce-6d127f8797ea/data/feature-table.biom -t /tmp/qiime2-archive-clbh86dl/a6875c1e-e1fb-438b-8a1a-780f1183e637/data/tree.nwk -m unweighted -o /tmp/q2-LSMatFormat-z6_5qgwe
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-fovn_h67/d15e4e70-d753-484e-a6ce-6d127f8797ea/data/feature-table.biom -t /tmp/qiime2-archive-clbh86dl/a6875c1e-e1fb-438b-8a1a-780f1183e637/data/tree.nwk -m weighted_unnormalized -o /tmp/q2-LSMatFormat-nan7xqle
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:143: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0013560874606786063 and the largest is 0.3058115796721099.
#   warn(

# %%
action_results.bray_curtis_distance_matrix.view(view_type=DistanceMatrix)

# %%
action_results.jaccard_distance_matrix.view(view_type=DistanceMatrix)

# %%
action_results.jaccard_emperor
# Out:
# <visualization: Visualization uuid: b8b350de-566c-470a-b58a-f831caa1364a>

# %%
depth = 14448

alpha_rarefaction = diversity.visualizers.alpha_rarefaction(
    table = denoisetable_eu,
    phylogeny = rooted_tree,
    max_depth = depth,
    metadata = sample_metadata,
    metrics = {'chao1', 'shannon', 'simpson', 'simpson_e', 'observed_features', 'fisher_alpha'},
    steps =  100
)

# %%
#alpha_rarefaction.visualization.save('./results/alpha_diversity.qzv')
alpha_rarefaction = q2.Visualization.load('./results/alpha_diversity.qzv')

# %%
metrics = ['chao1', 'shannon', 'simpson', 'simpson_e', 'observed_features', 'fisher_alpha']

# alpha diversity metrics and significance

# init empty list
df_list = []
artifacts = {}

# loop over metrics
for metric in metrics:
    result = diversity.actions.alpha(
        table = action_results.rarefied_table,
        metric = metric
    )  # save to result
    artifact = result.alpha_diversity  # extract artifact
    artifacts[metric] = artifact
    df_list.append(artifact.view(view_type=q2.Metadata).to_dataframe())  # convert to DF and add to list
    
df = pd.concat(df_list, axis=1)  # merge list of dataframes, add each DF as new column (instead of new row (default))
df
# Out:
#                 chao1  shannon_entropy   simpson  simpson_e  \
# Sample ID
# P01A        82.000000         3.241795  0.819708   0.075980
# P03A       132.666667         4.551302  0.887817   0.069641
# P05A        64.500000         3.551926  0.824196   0.099792
# P07A       183.333333         4.736431  0.814304   0.029752
# P09A        77.000000         1.793511  0.449838   0.025601
# P11A        86.000000         3.861979  0.815077   0.071153
# P13A       185.600000         3.713867  0.657876   0.015800
# P15A        64.000000         3.918573  0.886518   0.137687
# P17A        82.250000         2.853432  0.668455   0.036783
# P19A        56.000000         2.658340  0.606012   0.047890
# P20A        76.500000         3.961998  0.843562   0.084109
# P21A        65.000000         2.846145  0.662645   0.049404
# P22A        22.000000         2.737877  0.772599   0.199887
#
#            observed_features  fisher_alpha
# Sample ID
# P01A                    73.0     10.037579
# P03A                   128.0     19.343215
# P05A                    57.0      7.541231
# P07A                   181.0     29.157780
# P09A                    71.0      9.719582
# P11A                    76.0     10.517590
# P13A                   185.0     29.927516
# P15A                    64.0      8.619693
# P17A                    82.0     11.488150
# P19A                    53.0      6.935192
# P20A                    76.0     10.517590
# P21A                    60.0      8.000710
# P22A                    22.0      2.545015

# %%
# visualisations of alpha diversity metrics
visualizations = {}

for key, value in artifacts.items():
    visualizations[key] = diversity.visualizers.alpha_group_significance(
        alpha_diversity = value,
        metadata = sample_metadata
    ).visualization

# %%
# # simpson viz
# visualizations['simpson']

# # observed_features viz
# visualizations['observed_features']

# # fisher_alpha viz
# visualizations['fisher_alpha']

# # chao1 viz
# visualizations['chao1']

# # shannon viz
# visualizations['shannon']

# # evenness_vector viz
# diversity.visualizers.alpha_group_significance(
#     alpha_diversity = action_results.evenness_vector,
#     metadata = sample_metadata
# ).visualization

# # faith_pd viz
# diversity.visualizers.alpha_group_significance(
#     alpha_diversity = action_results.faith_pd_vector,
#     metadata = sample_metadata
# ).visualization

# %% [markdown]
# ### BETA DIVERSITY

# %%
denoisetable_subset_population = q2.plugins.feature_table.methods.filter_samples(
    table = denoisetable_eu,
    metadata = sample_metadata,
    where = "[population] IN ('linija reke Ljubljanice', 'črna podvrsta')"
)

# %%
# 2016 falls out
denoisetable_subset_year = q2.plugins.feature_table.methods.filter_samples(
    table = denoisetable_eu,
    metadata = sample_metadata,
    where = "[year] IN ('2015','2019')"
)

# %%
# determine depth/s from alpha_rarefaction
# determine conditions from metadata column names
depth = 14448
condition = 'population'

core_metrics_results_subset_population = diversity.actions.core_metrics_phylogenetic(
    phylogeny = rooted_tree,
    table = denoisetable_subset_population.filtered_table,
    sampling_depth = depth,
    metadata = sample_metadata
)
# Out:
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:1776: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /tmp/qiime2-archive-i92kw0ca/a8bfe767-c84f-434e-8887-b149d4bbfa86/data/feature-table.biom -t /tmp/qiime2-archive-clbh86dl/a6875c1e-e1fb-438b-8a1a-780f1183e637/data/tree.nwk -o /tmp/q2-AlphaDiversityFormat-etoj6dfd
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-i92kw0ca/a8bfe767-c84f-434e-8887-b149d4bbfa86/data/feature-table.biom -t /tmp/qiime2-archive-clbh86dl/a6875c1e-e1fb-438b-8a1a-780f1183e637/data/tree.nwk -m unweighted -o /tmp/q2-LSMatFormat-uitbpgnt
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-i92kw0ca/a8bfe767-c84f-434e-8887-b149d4bbfa86/data/feature-table.biom -t /tmp/qiime2-archive-clbh86dl/a6875c1e-e1fb-438b-8a1a-780f1183e637/data/tree.nwk -m weighted_unnormalized -o /tmp/q2-LSMatFormat-cuqwi0mm
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:143: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0006403948953556517 and the largest is 0.3066860226870208.
#   warn(

# %%
depth = 14448
condition = 'year'

core_metrics_results_subset_year = diversity.actions.core_metrics_phylogenetic(
    phylogeny = rooted_tree,
    table = denoisetable_subset_year.filtered_table,
    sampling_depth = depth,
    metadata = sample_metadata
)
# Out:
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:1776: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /tmp/qiime2-archive-8nvuw9g4/30dca714-36b1-4d50-82e0-6475d2e1d18a/data/feature-table.biom -t /tmp/qiime2-archive-clbh86dl/a6875c1e-e1fb-438b-8a1a-780f1183e637/data/tree.nwk -o /tmp/q2-AlphaDiversityFormat-oe3hmkbn
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-8nvuw9g4/30dca714-36b1-4d50-82e0-6475d2e1d18a/data/feature-table.biom -t /tmp/qiime2-archive-clbh86dl/a6875c1e-e1fb-438b-8a1a-780f1183e637/data/tree.nwk -m unweighted -o /tmp/q2-LSMatFormat-e51y3o_0
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-8nvuw9g4/30dca714-36b1-4d50-82e0-6475d2e1d18a/data/feature-table.biom -t /tmp/qiime2-archive-clbh86dl/a6875c1e-e1fb-438b-8a1a-780f1183e637/data/tree.nwk -m weighted_unnormalized -o /tmp/q2-LSMatFormat-2iq3192v
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:143: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.00016948022417087306 and the largest is 0.2408104276150301.
#   warn(

# %% [markdown]
# #### PERMANOVA

# %%
from qiime2.plugins.diversity.visualizers import beta_group_significance

permanova_population = beta_group_significance(
    distance_matrix = core_metrics_results_subset_population.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata.get_column('population'),
    method = "permanova",
    pairwise = True
)
permanova_population.visualization
# Out:
# <visualization: Visualization uuid: ee41a1c9-45fb-4991-ad66-0a3ad799965b>

# %%
# PERMANOVA year
from qiime2.plugins.diversity.visualizers import beta_group_significance

permanova_year = beta_group_significance(
    distance_matrix = core_metrics_results_subset_year.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata.get_column('year'),
    method = "permanova",
    pairwise = True
)
permanova_year.visualization
# Out:
# <visualization: Visualization uuid: 87d9d505-690e-42fe-8125-8703be95f430>

# %% [markdown]
# #### ANOSIM

# %%
anosim_population = beta_group_significance(
    distance_matrix = core_metrics_results_subset_population.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata.get_column('population'),
    method = "anosim",
    pairwise = True
)
anosim_population.visualization
# Out:
# <visualization: Visualization uuid: dfb36111-e847-42cd-807c-8a6bd2f67e01>

# %%
# anosim year

anosim_year = beta_group_significance(
    distance_matrix = core_metrics_results_subset_year.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata.get_column('year'),
    method = "anosim",
    pairwise = True
)
anosim_year.visualization
# Out:
# <visualization: Visualization uuid: fd807ad3-928d-469a-8008-b657664f59a0>
