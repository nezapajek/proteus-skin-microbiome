# %% [markdown]
# # EUKARYA

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# %matplotlib inline

# %% [markdown]
# ### ALPHA & BETA DIVERSITY
# 1. make a MAFFT tree
# 2. alpha rarefaction
# 3. alpha diversity
# 4. beta diversity

# %%
#import packages
import os
import dokdo
import qiime2 as q2
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from qiime2.plugins import phylogeny
from qiime2.plugins import diversity
from skbio import DistanceMatrix
import qiime2.plugins.phylogeny.actions as phylogeny_actions

# %%
# define workdir
# %env WORKDIR /home/nezapa/qiime-thesis
WORKDIR = os.environ.get("WORKDIR")
# Out:
# env: WORKDIR=/home/nezapa/qiime-thesis

# %%
# import data
denoisetable_eu = q2.Artifact.load('./results/denoisetable_eu.qza')
rep_seqs_eu = q2.Artifact.load('./results/rep_seqs_eu.qza')
denoising_stats = q2.Artifact.load('./results/denoising_stats.qza')
sample_metadata = q2.Metadata.load('../00.sample-metadata.tsv')

# %% [markdown]
# ## TREE

# %%
action_results = phylogeny_actions.align_to_tree_mafft_fasttree(
    sequences=rep_seqs_eu,
)
aligned_rep_seqs = action_results.alignment
masked_aligned_rep_seqs = action_results.masked_alignment
unrooted_tree = action_results.tree
rooted_tree = action_results.rooted_tree
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: mafft --preservecase --inputorder --thread 1 /tmp/qiime2-archive-9wf4bwol/fe57d111-ef42-4817-9c9d-0ca8acdcdea2/data/dna-sequences.fasta
# inputfile = orig
# 578 x 260 - 260 d
# nthread = 1
# nthreadpair = 1
# nthreadtb = 1
# ppenalty_ex = 0
# stacksize: 8192 kb
# generating a scoring matrix for nucleotide (dist=200) ... done
# Gap Penalty = -1.53, +0.00, +0.00
#
#
#
# Making a distance matrix ..
#   501 / 578 (thread    0)
# done.
#
# Constructing a UPGMA tree (efffree=0) ...
#   570 / 578
# done.
#
# Progressive alignment 1/2...
# STEP    63 / 577 (thread    0)
# Reallocating..done. *alloclen = 1521
# STEP   501 / 577 (thread    0) h
# done.
#
# Making a distance matrix from msa..
#   500 / 578 (thread    0)
# done.
#
# Constructing a UPGMA tree (efffree=1) ...
#   570 / 578
# done.
#
# Progressive alignment 2/2...
# STEP   470 / 577 (thread    0) h
# Reallocating..done. *alloclen = 1521
# STEP   501 / 577 (thread    0) h
# done.
#
# disttbfast (nuc) Version 7.505
# alg=A, model=DNA200 (2), 1.53 (4.59), -0.00 (-0.00), noshift, amax=0.0
# 1 thread(s)
#
#
# Strategy:
#  FFT-NS-2 (Fast but rough)
#  Progressive method (guide trees were built 2 times.)
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: FastTree -quote -nt /tmp/qiime2-archive-n478ii2l/37182ad1-d234-45ee-b275-9b12724bb873/data/aligned-dna-sequences.fasta
# FastTree Version 2.1.10 Double precision (No SSE3)
# Alignment: /tmp/qiime2-archive-n478ii2l/37182ad1-d234-45ee-b275-9b12724bb873/data/aligned-dna-sequences.fasta
# Nucleotide distances: Jukes-Cantor Joins: balanced Support: SH-like 1000
# Search: Normal +NNI +SPR (2 rounds range 10) +ML-NNI opt-each=1
# TopHits: 1.00*sqrtN close=default refresh=0.80
# ML Model: Jukes-Cantor, CAT approximation with 20 rate categories
#       0.11 seconds: Top hits for    511 of    578 seqs (at seed    500)
#       0.24 seconds: Joined    200 of    575
#       0.40 seconds: Joined    400 of    575
# Initial topology in 0.50 seconds
# Refining topology: 37 rounds ME-NNIs, 2 rounds ME-SPRs, 18 rounds ML-NNIs
#       0.50 seconds: ME NNI round 1 of 37, 101 of 576 splits, 13 changes (max delta 0.002)
#       0.67 seconds: SPR round   1 of   2, 101 of 1154 nodes
#       0.84 seconds: SPR round   1 of   2, 301 of 1154 nodes
#       1.02 seconds: SPR round   1 of   2, 501 of 1154 nodes
#       1.20 seconds: SPR round   1 of   2, 701 of 1154 nodes
#       1.38 seconds: SPR round   1 of   2, 901 of 1154 nodes
#       1.54 seconds: SPR round   1 of   2, 1101 of 1154 nodes
#       1.65 seconds: ME NNI round 16 of 37, 1 of 576 splits
#       1.81 seconds: SPR round   2 of   2, 201 of 1154 nodes
#       1.99 seconds: SPR round   2 of   2, 401 of 1154 nodes
#       2.17 seconds: SPR round   2 of   2, 601 of 1154 nodes
#       2.35 seconds: SPR round   2 of   2, 801 of 1154 nodes
#       2.53 seconds: SPR round   2 of   2, 1001 of 1154 nodes
#       2.65 seconds: ME NNI round 25 of 37, 1 of 576 splits
# Total branch-length 11.708 after 2.74 sec
#       2.79 seconds: ML Lengths 101 of 576 splits
#       2.90 seconds: ML Lengths 301 of 576 splits
#       3.00 seconds: ML Lengths 501 of 576 splits
#       3.20 seconds: ML NNI round 1 of 18, 101 of 576 splits, 36 changes (max delta 1.377)
#       3.37 seconds: ML NNI round 1 of 18, 201 of 576 splits, 77 changes (max delta 1.603)
#       3.53 seconds: ML NNI round 1 of 18, 301 of 576 splits, 114 changes (max delta 2.473)
#       3.70 seconds: ML NNI round 1 of 18, 401 of 576 splits, 150 changes (max delta 2.473)
#       3.87 seconds: ML NNI round 1 of 18, 501 of 576 splits, 188 changes (max delta 5.740)
# ML-NNI round 1: LogLk = -16052.846 NNIs 215 max delta 5.74 Time 4.02
#       4.02 seconds: Site likelihoods with rate category 1 of 20
#       4.13 seconds: Site likelihoods with rate category 10 of 20
#       4.23 seconds: Site likelihoods with rate category 19 of 20
# Switched to using 20 rate categories (CAT approximation)
# Rate categories were divided by 0.819 so that average rate = 1.0
# CAT-based log-likelihoods may not be comparable across runs
# Use -gamma for approximate but comparable Gamma(20) log-likelihoods
#       4.39 seconds: ML NNI round 2 of 18, 101 of 576 splits, 30 changes (max delta 1.060)
#       4.53 seconds: ML NNI round 2 of 18, 201 of 576 splits, 49 changes (max delta 1.060)
#       4.67 seconds: ML NNI round 2 of 18, 301 of 576 splits, 66 changes (max delta 1.060)
#       4.81 seconds: ML NNI round 2 of 18, 401 of 576 splits, 85 changes (max delta 1.060)
#       4.97 seconds: ML NNI round 2 of 18, 501 of 576 splits, 108 changes (max delta 1.060)
# ML-NNI round 2: LogLk = -15464.419 NNIs 120 max delta 7.86 Time 5.08
#       5.07 seconds: ML NNI round 3 of 18, 1 of 576 splits
#       5.21 seconds: ML NNI round 3 of 18, 101 of 576 splits, 13 changes (max delta 2.939)
#       5.35 seconds: ML NNI round 3 of 18, 201 of 576 splits, 30 changes (max delta 2.939)
#       5.47 seconds: ML NNI round 3 of 18, 301 of 576 splits, 41 changes (max delta 2.939)
#       5.59 seconds: ML NNI round 3 of 18, 401 of 576 splits, 47 changes (max delta 2.939)
# ML-NNI round 3: LogLk = -15457.033 NNIs 66 max delta 2.94 Time 5.71
#       5.71 seconds: ML NNI round 4 of 18, 1 of 576 splits
#       5.83 seconds: ML NNI round 4 of 18, 101 of 576 splits, 6 changes (max delta 0.001)
#       5.96 seconds: ML NNI round 4 of 18, 201 of 576 splits, 24 changes (max delta 0.001)
#       6.08 seconds: ML NNI round 4 of 18, 301 of 576 splits, 37 changes (max delta 0.001)
# ML-NNI round 4: LogLk = -15456.400 NNIs 41 max delta 0.00 Time 6.18
# Turning off heuristics for final round of ML NNIs (converged)
#       6.35 seconds: ML NNI round 5 of 18, 101 of 576 splits, 1 changes (max delta 0.000)
#       6.50 seconds: ML NNI round 5 of 18, 201 of 576 splits, 7 changes (max delta 0.000)
#       6.66 seconds: ML NNI round 5 of 18, 301 of 576 splits, 13 changes (max delta 0.000)
#       6.81 seconds: ML NNI round 5 of 18, 401 of 576 splits, 20 changes (max delta 0.000)
#       6.96 seconds: ML NNI round 5 of 18, 501 of 576 splits, 26 changes (max delta 0.000)
# ML-NNI round 5: LogLk = -15453.232 NNIs 32 max delta 0.00 Time 7.08 (final)
#       7.07 seconds: ML Lengths 1 of 576 splits
#       7.19 seconds: ML Lengths 301 of 576 splits
# Optimize all lengths: LogLk = -15453.149 Time 7.30
#       7.53 seconds: ML split tests for    100 of    575 internal splits
#       7.74 seconds: ML split tests for    200 of    575 internal splits
#       7.96 seconds: ML split tests for    300 of    575 internal splits
#       8.17 seconds: ML split tests for    400 of    575 internal splits
#       8.38 seconds: ML split tests for    500 of    575 internal splits
# Total time: 8.54 seconds Unique: 578/578 Bad splits: 0/575

# %% [markdown]
# ## ALPHA AND BETA DIVERSITY

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# # choose a round number in the 3rd quartile frequency per sample from the feature table visual summary
# # this step can take some time
# alpha_rarefaction_all = diversity.actions.alpha_rarefaction(
#     table = denoisetable_eu,
#     max_depth = 30000,
#     phylogeny = rooted_tree,
#     metrics = {'observed_features'},
#     metadata = sample_metadata,
#     steps = 1000
# )

# %%
# save alpha_rarefacion
# alpha_rarefaction_all.visualization.save('./results/alpha_rarefaction_30000.qzv')
qzv_file_alpha = q2.Visualization.load('./results/alpha_rarefaction_30000.qzv')

# %%
# sns.set()
# ax = dokdo.alpha_rarefaction_plot(qzv_file_alpha,
#                                   figsize=(9, 6),
#                                   metric='observed_features')
# ax.legend(ncol=5)
# plt.tight_layout()
# plt.savefig('./results/eu_alpha_rarefaction_plot.png')

# %% [markdown]
# ### ALPHA DIVERSITY

# %%
# set sampling_depth based on alpha rarefacation curve
depth = 14400
action_results = diversity.actions.core_metrics_phylogenetic(
    table = denoisetable_eu,
    phylogeny = rooted_tree,
    sampling_depth = depth,
    metadata = sample_metadata
)
# Out:
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:1776: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /tmp/qiime2-archive-ww5ut9pq/7224dfbf-12c7-40f1-aa97-a9a4fd5ad474/data/feature-table.biom -t /tmp/qiime2-archive-aa5qs_er/b0d16da9-e6ed-42a4-9809-38866c86e386/data/tree.nwk -o /tmp/q2-AlphaDiversityFormat-n4w35bie
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-ww5ut9pq/7224dfbf-12c7-40f1-aa97-a9a4fd5ad474/data/feature-table.biom -t /tmp/qiime2-archive-aa5qs_er/b0d16da9-e6ed-42a4-9809-38866c86e386/data/tree.nwk -m unweighted -o /tmp/q2-LSMatFormat-m4qfmjgz
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-ww5ut9pq/7224dfbf-12c7-40f1-aa97-a9a4fd5ad474/data/feature-table.biom -t /tmp/qiime2-archive-aa5qs_er/b0d16da9-e6ed-42a4-9809-38866c86e386/data/tree.nwk -m weighted_unnormalized -o /tmp/q2-LSMatFormat-kpq3a375
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:143: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.001482911913163081 and the largest is 0.3696862520457212.
#   warn(

# %%
action_results.bray_curtis_distance_matrix.view(view_type=DistanceMatrix)

# %%
action_results.jaccard_distance_matrix.view(view_type=DistanceMatrix)

# %%
action_results.jaccard_emperor
# Out:
# <visualization: Visualization uuid: ab3d7a78-92c0-4134-8acf-2e46b2766ab2>

# %%
# alpha_rarefaction = diversity.visualizers.alpha_rarefaction(
#     table = denoisetable_eu,
#     phylogeny = rooted_tree,
#     max_depth = depth,
#     metadata = sample_metadata,
#     metrics = {'chao1', 'shannon', 'simpson', 'simpson_e', 'observed_features', 'fisher_alpha'},
#     steps =  1000
# )

# %%
# alpha_rarefaction.visualization.save('./results/alpha_diversity.qzv')
alpha_rarefaction = q2.Visualization.load('./results/alpha_diversity.qzv')

# %%
metrics = ['observed_features', 'fisher_alpha', 'chao1', 'shannon', 'simpson']

# alpha diversity metrics and significance

# init empty list
df_list = []
artifacts = {}

# loop over metrics
for metric in metrics:
    result = diversity.actions.alpha(
        table = action_results.rarefied_table,
        metric = metric
    )  # save to result
    artifact = result.alpha_diversity  # extract artifact
    artifacts[metric] = artifact
    df_list.append(artifact.view(view_type=q2.Metadata).to_dataframe())  # convert to DF and add to list
    
df = pd.concat(df_list, axis=1)  # merge list of dataframes, add each DF as new column (instead of new row (default))
df
# Out:
#            observed_features  fisher_alpha       chao1  shannon_entropy  \
# Sample ID
# P01A                    68.0      9.250509   70.500000         3.252425
# P03A                   128.0     19.354663  132.000000         4.512114
# P05A                    57.0      7.545057   58.200000         3.545258
# P07A                   182.0     29.368600  185.272727         4.767847
# P09A                    70.0      9.566228   97.500000         1.776521
# P11A                    75.0     10.362710   76.500000         3.874481
# P13A                   185.0     29.946703  191.000000         3.623283
# P15A                    64.0      8.624157   64.000000         3.917625
# P17A                    85.0     11.985077   90.250000         2.835022
# P19A                    51.0      6.638401   51.333333         2.629478
# P20A                    76.0     10.523210   77.000000         3.968978
# P21A                    59.0      7.851095   62.000000         2.799013
# P22A                    22.0      2.546123   22.000000         2.742353
#
#             simpson
# Sample ID
# P01A       0.818614
# P03A       0.883198
# P05A       0.822726
# P07A       0.819218
# P09A       0.444328
# P11A       0.817109
# P13A       0.645953
# P15A       0.886440
# P17A       0.664543
# P19A       0.601923
# P20A       0.843667
# P21A       0.653603
# P22A       0.773721

# %%
# visualisations of alpha diversity metrics
visualizations = {}

for key, value in artifacts.items():
    visualizations[key] = diversity.visualizers.alpha_group_significance(
        alpha_diversity = value,
        metadata = sample_metadata
    ).visualization

# %%
# simpson viz
visualizations['simpson']
# Out:
# <visualization: Visualization uuid: 1f7549e8-d09e-40de-bb7d-1a673b0e9045>

# %%
# observed_features viz
visualizations['observed_features']
# Out:
# <visualization: Visualization uuid: 1cda8d9c-69da-461d-829b-39246c96c818>

# %%
# fisher_alpha viz
visualizations['fisher_alpha']
# Out:
# <visualization: Visualization uuid: dde1f160-63fc-46af-b01b-228a246ce7e6>

# %%
# chao1 viz
visualizations['chao1']
# Out:
# <visualization: Visualization uuid: 078b3044-8bbe-4769-893d-51542e656a03>

# %%
# shannon viz
visualizations['shannon']
# Out:
# <visualization: Visualization uuid: 5aa0d6bd-ce6a-4fa6-8e53-4829314355a6>

# %%
# evenness_vector viz
diversity.visualizers.alpha_group_significance(
    alpha_diversity = action_results.evenness_vector,
    metadata = sample_metadata
).visualization
# Out:
# <visualization: Visualization uuid: 6c219610-581c-4859-9761-d4ff3665c14d>

# %%
# faith_pd viz
diversity.visualizers.alpha_group_significance(
    alpha_diversity = action_results.faith_pd_vector,
    metadata = sample_metadata
).visualization
# Out:
# <visualization: Visualization uuid: 80eb9447-682f-42f6-af2a-121f2a880ebc>

# %% [markdown]
# ### BETA DIVERSITY

# %%
denoisetable_subset_population = q2.plugins.feature_table.methods.filter_samples(
    table = denoisetable_eu,
    metadata = sample_metadata,
    where = "[population] IN ('linija reke Ljubljanice', 'črna podvrsta')"
)

# %%
# 2016 falls out
denoisetable_subset_year = q2.plugins.feature_table.methods.filter_samples(
    table = denoisetable_eu,
    metadata = sample_metadata,
    where = "[year] IN ('2015','2019')"
)

# %%
# determine depth/s from alpha_rarefaction
# determine conditions from metadata column names
depth = 25000
condition = 'population'

core_metrics_results_subset_population = diversity.actions.core_metrics_phylogenetic(
    phylogeny = rooted_tree,
    table = denoisetable_subset_population.filtered_table,
    sampling_depth = depth,
    metadata = sample_metadata
)
# Out:
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:1776: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /tmp/qiime2-archive-xt4rs5m2/f886b7d4-1383-4c7c-ba88-826c59292f1a/data/feature-table.biom -t /tmp/qiime2-archive-aa5qs_er/b0d16da9-e6ed-42a4-9809-38866c86e386/data/tree.nwk -o /tmp/q2-AlphaDiversityFormat-v0zq5kkw
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-xt4rs5m2/f886b7d4-1383-4c7c-ba88-826c59292f1a/data/feature-table.biom -t /tmp/qiime2-archive-aa5qs_er/b0d16da9-e6ed-42a4-9809-38866c86e386/data/tree.nwk -m unweighted -o /tmp/q2-LSMatFormat-girha_qo
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-xt4rs5m2/f886b7d4-1383-4c7c-ba88-826c59292f1a/data/feature-table.biom -t /tmp/qiime2-archive-aa5qs_er/b0d16da9-e6ed-42a4-9809-38866c86e386/data/tree.nwk -m weighted_unnormalized -o /tmp/q2-LSMatFormat-qmyy5dh1

# %%
depth = 25000
condition = 'year'

core_metrics_results_subset_year = diversity.actions.core_metrics_phylogenetic(
    phylogeny = rooted_tree,
    table = denoisetable_subset_year.filtered_table,
    sampling_depth = depth,
    metadata = sample_metadata
)
# Out:
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:1776: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /tmp/qiime2-archive-0k332bgu/ac023c43-44c9-4f81-9d35-0eab0e7b9666/data/feature-table.biom -t /tmp/qiime2-archive-aa5qs_er/b0d16da9-e6ed-42a4-9809-38866c86e386/data/tree.nwk -o /tmp/q2-AlphaDiversityFormat-2pqbba4x
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-0k332bgu/ac023c43-44c9-4f81-9d35-0eab0e7b9666/data/feature-table.biom -t /tmp/qiime2-archive-aa5qs_er/b0d16da9-e6ed-42a4-9809-38866c86e386/data/tree.nwk -m unweighted -o /tmp/q2-LSMatFormat-y2u59b0y
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-0k332bgu/ac023c43-44c9-4f81-9d35-0eab0e7b9666/data/feature-table.biom -t /tmp/qiime2-archive-aa5qs_er/b0d16da9-e6ed-42a4-9809-38866c86e386/data/tree.nwk -m weighted_unnormalized -o /tmp/q2-LSMatFormat-23lvzhrw

# %% [markdown]
# #### PERMANOVA

# %%
from qiime2.plugins.diversity.visualizers import beta_group_significance

permanova_population = beta_group_significance(
    distance_matrix = core_metrics_results_subset_population.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata.get_column('population'),
    method = "permanova",
    pairwise = True
)
permanova_population.visualization
# Out:
# <visualization: Visualization uuid: 05838fe8-d97e-4307-9c47-2e11c28d00d6>

# %%
# PERMANOVA year
from qiime2.plugins.diversity.visualizers import beta_group_significance

permanova_year = beta_group_significance(
    distance_matrix = core_metrics_results_subset_year.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata.get_column('year'),
    method = "permanova",
    pairwise = True
)
permanova_year.visualization
# Out:
# <visualization: Visualization uuid: a0f73ebf-e565-4ec9-b99a-9e5f564db61c>

# %% [markdown]
# #### ANOSIM

# %%
anosim_population = beta_group_significance(
    distance_matrix = core_metrics_results_subset_population.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata.get_column('population'),
    method = "anosim",
    pairwise = True
)
anosim_population.visualization
# Out:
# <visualization: Visualization uuid: 538519f1-f781-4d98-98a9-18783a391213>

# %%
# anosim year

anosim_year = beta_group_significance(
    distance_matrix = core_metrics_results_subset_year.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata.get_column('year'),
    method = "anosim",
    pairwise = True
)
anosim_year.visualization
# Out:
# <visualization: Visualization uuid: 871e84df-6973-4ffb-add9-aca36a581e0c>
