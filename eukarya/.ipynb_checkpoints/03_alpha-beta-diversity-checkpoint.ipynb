# %% [markdown]
# # EUKARYA

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# %matplotlib inline

# %% [markdown]
# ### ALPHA & BETA DIVERSITY
# 1. make a MAFFT tree
# 2. alpha rarefaction
# 3. alpha diversity
# 4. beta diversity

# %%
#import packages
import os
import dokdo
import qiime2 as q2
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from qiime2.plugins import phylogeny
from qiime2.plugins import diversity
from skbio import DistanceMatrix
import qiime2.plugins.phylogeny.actions as phylogeny_actions

# %%
# define workdir
# %env WORKDIR /home/nezapa/qiime-thesis
WORKDIR = os.environ.get("WORKDIR")
# Out:
# env: WORKDIR=/home/nezapa/qiime-thesis

# %%
# import data
denoisetable_eu = q2.Artifact.load('./results/denoisetable_eu.qza')
rep_seqs_eu = q2.Artifact.load('./results/rep_seqs_eu.qza')
denoising_stats = q2.Artifact.load('./results/denoising_stats.qza')
sample_metadata = q2.Metadata.load('../00.sample-metadata.tsv')

# %% [markdown]
# ## TREE

# %%
action_results = phylogeny_actions.align_to_tree_mafft_fasttree(
    sequences=rep_seqs_eu,
)
aligned_rep_seqs = action_results.alignment
masked_aligned_rep_seqs = action_results.masked_alignment
unrooted_tree = action_results.tree
rooted_tree = action_results.rooted_tree
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: mafft --preservecase --inputorder --thread 1 /tmp/qiime2-archive-66pj6co2/e468b077-912f-4bc6-8c32-a61c975c3cab/data/dna-sequences.fasta
# inputfile = orig
# 578 x 260 - 260 d
# nthread = 1
# nthreadpair = 1
# nthreadtb = 1
# ppenalty_ex = 0
# stacksize: 8192 kb
# generating a scoring matrix for nucleotide (dist=200) ... done
# Gap Penalty = -1.53, +0.00, +0.00
#
#
#
# Making a distance matrix ..
#   501 / 578 (thread    0)
# done.
#
# Constructing a UPGMA tree (efffree=0) ...
#   570 / 578
# done.
#
# Progressive alignment 1/2...
# STEP    67 / 577 (thread    0)
# Reallocating..done. *alloclen = 1521
# STEP   501 / 577 (thread    0) h
# done.
#
# Making a distance matrix from msa..
#   500 / 578 (thread    0)
# done.
#
# Constructing a UPGMA tree (efffree=1) ...
#   570 / 578
# done.
#
# Progressive alignment 2/2...
# STEP   470 / 577 (thread    0) h
# Reallocating..done. *alloclen = 1521
# STEP   501 / 577 (thread    0) h
# done.
#
# disttbfast (nuc) Version 7.505
# alg=A, model=DNA200 (2), 1.53 (4.59), -0.00 (-0.00), noshift, amax=0.0
# 1 thread(s)
#
#
# Strategy:
#  FFT-NS-2 (Fast but rough)
#  Progressive method (guide trees were built 2 times.)
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: FastTree -quote -nt /tmp/qiime2-archive-tdnhkru0/36cbc450-2a47-4228-bbe6-88d00b90a1f6/data/aligned-dna-sequences.fasta
# FastTree Version 2.1.10 Double precision (No SSE3)
# Alignment: /tmp/qiime2-archive-tdnhkru0/36cbc450-2a47-4228-bbe6-88d00b90a1f6/data/aligned-dna-sequences.fasta
# Nucleotide distances: Jukes-Cantor Joins: balanced Support: SH-like 1000
# Search: Normal +NNI +SPR (2 rounds range 10) +ML-NNI opt-each=1
# TopHits: 1.00*sqrtN close=default refresh=0.80
# ML Model: Jukes-Cantor, CAT approximation with 20 rate categories
#       0.12 seconds: Top hits for    519 of    578 seqs (at seed    500)
#       0.24 seconds: Joined    200 of    575
#       0.38 seconds: Joined    400 of    575
# Initial topology in 0.49 seconds
# Refining topology: 37 rounds ME-NNIs, 2 rounds ME-SPRs, 18 rounds ML-NNIs
#       0.49 seconds: ME NNI round 1 of 37, 101 of 576 splits, 16 changes (max delta 0.003)
#       0.59 seconds: SPR round   1 of   2, 1 of 1154 nodes
#       0.77 seconds: SPR round   1 of   2, 201 of 1154 nodes
#       0.96 seconds: SPR round   1 of   2, 401 of 1154 nodes
#       1.13 seconds: SPR round   1 of   2, 601 of 1154 nodes
#       1.31 seconds: SPR round   1 of   2, 801 of 1154 nodes
#       1.49 seconds: SPR round   1 of   2, 1001 of 1154 nodes
#       1.61 seconds: ME NNI round 13 of 37, 1 of 576 splits
#       1.74 seconds: SPR round   2 of   2, 101 of 1154 nodes
#       1.91 seconds: SPR round   2 of   2, 301 of 1154 nodes
#       2.10 seconds: SPR round   2 of   2, 501 of 1154 nodes
#       2.29 seconds: SPR round   2 of   2, 701 of 1154 nodes
#       2.45 seconds: SPR round   2 of   2, 901 of 1154 nodes
#       2.62 seconds: SPR round   2 of   2, 1101 of 1154 nodes
#       2.72 seconds: ME NNI round 26 of 37, 401 of 576 splits, 4 changes (max delta 0.000)
# Total branch-length 11.768 after 2.77 sec
#       2.82 seconds: ML Lengths 101 of 576 splits
#       2.92 seconds: ML Lengths 301 of 576 splits
#       3.03 seconds: ML Lengths 501 of 576 splits
#       3.23 seconds: ML NNI round 1 of 18, 101 of 576 splits, 35 changes (max delta 2.473)
#       3.40 seconds: ML NNI round 1 of 18, 201 of 576 splits, 54 changes (max delta 4.173)
#       3.57 seconds: ML NNI round 1 of 18, 301 of 576 splits, 95 changes (max delta 5.560)
#       3.73 seconds: ML NNI round 1 of 18, 401 of 576 splits, 134 changes (max delta 5.560)
#       3.90 seconds: ML NNI round 1 of 18, 501 of 576 splits, 172 changes (max delta 5.560)
# ML-NNI round 1: LogLk = -16127.912 NNIs 206 max delta 5.56 Time 4.03
#       4.04 seconds: Site likelihoods with rate category 1 of 20
#       4.14 seconds: Site likelihoods with rate category 10 of 20
#       4.25 seconds: Site likelihoods with rate category 19 of 20
# Switched to using 20 rate categories (CAT approximation)
# Rate categories were divided by 0.820 so that average rate = 1.0
# CAT-based log-likelihoods may not be comparable across runs
# Use -gamma for approximate but comparable Gamma(20) log-likelihoods
#       4.40 seconds: ML NNI round 2 of 18, 101 of 576 splits, 20 changes (max delta 0.000)
#       4.55 seconds: ML NNI round 2 of 18, 201 of 576 splits, 33 changes (max delta 0.215)
#       4.69 seconds: ML NNI round 2 of 18, 301 of 576 splits, 52 changes (max delta 0.215)
#       4.83 seconds: ML NNI round 2 of 18, 401 of 576 splits, 73 changes (max delta 1.708)
#       4.96 seconds: ML NNI round 2 of 18, 501 of 576 splits, 85 changes (max delta 7.058)
# ML-NNI round 2: LogLk = -15534.146 NNIs 102 max delta 7.06 Time 5.07
#       5.07 seconds: ML NNI round 3 of 18, 1 of 576 splits
#       5.20 seconds: ML NNI round 3 of 18, 101 of 576 splits, 6 changes (max delta 2.945)
#       5.32 seconds: ML NNI round 3 of 18, 201 of 576 splits, 20 changes (max delta 2.945)
#       5.45 seconds: ML NNI round 3 of 18, 301 of 576 splits, 29 changes (max delta 2.945)
#       5.57 seconds: ML NNI round 3 of 18, 401 of 576 splits, 43 changes (max delta 2.945)
# ML-NNI round 3: LogLk = -15530.364 NNIs 50 max delta 2.95 Time 5.66
#       5.77 seconds: ML NNI round 4 of 18, 101 of 576 splits, 11 changes (max delta 0.000)
#       5.89 seconds: ML NNI round 4 of 18, 201 of 576 splits, 20 changes (max delta 0.000)
#       6.02 seconds: ML NNI round 4 of 18, 301 of 576 splits, 30 changes (max delta 0.000)
# ML-NNI round 4: LogLk = -15529.848 NNIs 30 max delta 0.00 Time 6.04
# Turning off heuristics for final round of ML NNIs (converged)
#       6.19 seconds: ML NNI round 5 of 18, 101 of 576 splits, 0 changes
#       6.33 seconds: ML NNI round 5 of 18, 201 of 576 splits, 10 changes (max delta 0.265)
#       6.47 seconds: ML NNI round 5 of 18, 301 of 576 splits, 13 changes (max delta 0.265)
#       6.62 seconds: ML NNI round 5 of 18, 401 of 576 splits, 18 changes (max delta 0.265)
#       6.80 seconds: ML NNI round 5 of 18, 501 of 576 splits, 23 changes (max delta 0.265)
# ML-NNI round 5: LogLk = -15528.020 NNIs 28 max delta 0.26 Time 6.92 (final)
#       6.92 seconds: ML Lengths 1 of 576 splits
#       7.03 seconds: ML Lengths 301 of 576 splits
# Optimize all lengths: LogLk = -15527.961 Time 7.15
#       7.36 seconds: ML split tests for    100 of    575 internal splits
#       7.58 seconds: ML split tests for    200 of    575 internal splits
#       7.79 seconds: ML split tests for    300 of    575 internal splits
#       8.00 seconds: ML split tests for    400 of    575 internal splits
#       8.22 seconds: ML split tests for    500 of    575 internal splits
# Total time: 8.38 seconds Unique: 578/578 Bad splits: 0/575

# %% [markdown]
# ## ALPHA AND BETA DIVERSITY

# %%
from qiime2.plugins import feature_table

# summarise and visualise
feature_table.visualizers.summarize(
    table = denoisetable_eu,
    sample_metadata = sample_metadata
).visualization
# Out:
# <visualization: Visualization uuid: 9d80a431-abc0-4b1b-bdb0-e80ef4eaecc3>

# %%
# # choose a round number in the 3rd quartile frequency per sample from the feature table visual summary
# # this step can take some time
# alpha_rarefaction_all = diversity.actions.alpha_rarefaction(
#     table = denoisetable_eu,
#     max_depth = 30000,
#     phylogeny = rooted_tree,
#     metrics = {'observed_features'},
#     metadata = sample_metadata,
#     steps = 1000
# )

# %%
# save alpha_rarefacion
# alpha_rarefaction_all.visualization.save('./results/alpha_rarefaction_30000.qzv')
qzv_file_alpha = q2.Visualization.load('./results/alpha_rarefaction_30000.qzv')

# %%
# sns.set()
# ax = dokdo.alpha_rarefaction_plot(qzv_file_alpha,
#                                   figsize=(9, 6),
#                                   metric='observed_features')
# ax.legend(ncol=5)
# plt.tight_layout()
# plt.savefig('./results/eu_alpha_rarefaction_plot.png')

# %% [markdown]
# ### ALPHA DIVERSITY

# %%
# set sampling_depth based on alpha rarefacation curve
depth = 14448
action_results = diversity.actions.core_metrics_phylogenetic(
    table = denoisetable_eu,
    phylogeny = rooted_tree,
    sampling_depth = depth,
    metadata = sample_metadata
)
# Out:
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:1776: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /tmp/qiime2-archive-9b428n6z/d3822a87-c71d-4144-b1a9-c4400e364266/data/feature-table.biom -t /tmp/qiime2-archive-ww1jz9ue/705f2128-028c-4219-902a-fd476faf6e8a/data/tree.nwk -o /tmp/q2-AlphaDiversityFormat-4i3q3z6w
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-9b428n6z/d3822a87-c71d-4144-b1a9-c4400e364266/data/feature-table.biom -t /tmp/qiime2-archive-ww1jz9ue/705f2128-028c-4219-902a-fd476faf6e8a/data/tree.nwk -m unweighted -o /tmp/q2-LSMatFormat-4l9thutz
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-9b428n6z/d3822a87-c71d-4144-b1a9-c4400e364266/data/feature-table.biom -t /tmp/qiime2-archive-ww1jz9ue/705f2128-028c-4219-902a-fd476faf6e8a/data/tree.nwk -m weighted_unnormalized -o /tmp/q2-LSMatFormat-g1v6d54_
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:143: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0019032407843228173 and the largest is 0.35659210909219863.
#   warn(

# %%
action_results.bray_curtis_distance_matrix.view(view_type=DistanceMatrix)

# %%
action_results.jaccard_distance_matrix.view(view_type=DistanceMatrix)

# %%
action_results.jaccard_emperor
# Out:
# <visualization: Visualization uuid: 6715fda1-e148-4a08-ac12-b9327da0b8f9>

# %%
# depth = 14448

# alpha_rarefaction = diversity.visualizers.alpha_rarefaction(
#     table = denoisetable_eu,
#     phylogeny = rooted_tree,
#     max_depth = depth,
#     metadata = sample_metadata,
#     metrics = {'chao1', 'shannon', 'simpson', 'simpson_e', 'observed_features', 'fisher_alpha'},
#     steps =  100
# )

#alpha_rarefaction.visualization.save('./results/alpha_diversity.qzv')
alpha_rarefaction = q2.Visualization.load('./results/alpha_diversity.qzv')

# %%
# load alpha_rarefacion
alpha_rar = q2.Visualization.load('./results/alpha_diversity.qzv')
alpha_rar
# Out:
# <visualization: Visualization uuid: ac88483c-7258-43b4-82d9-6e4ceaa05090>

# %%
metrics = ['chao1', 'shannon', 'simpson', 'simpson_e', 'observed_features', 'fisher_alpha']

# alpha diversity metrics and significance

# init empty list
df_list = []
artifacts = {}

# loop over metrics
for metric in metrics:
    result = diversity.actions.alpha(
        table = action_results.rarefied_table,
        metric = metric
    )  # save to result
    artifact = result.alpha_diversity  # extract artifact
    artifacts[metric] = artifact
    df_list.append(artifact.view(view_type=q2.Metadata).to_dataframe())  # convert to DF and add to list
    
df = pd.concat(df_list, axis=1)  # merge list of dataframes, add each DF as new column (instead of new row (default))
df
# Out:
#                 chao1  shannon_entropy   simpson  simpson_e  \
# Sample ID
# P01A        84.000000         3.267673  0.820207   0.077249
# P03A       130.000000         4.537154  0.886300   0.068712
# P05A        56.200000         3.546309  0.823559   0.101207
# P07A       186.090909         4.736462  0.814306   0.029589
# P09A        71.500000         1.787960  0.450243   0.026750
# P11A        79.000000         3.836199  0.810914   0.069587
# P13A       190.500000         3.656392  0.648802   0.015227
# P15A        64.000000         3.918573  0.886518   0.137687
# P17A        85.666667         2.864022  0.670084   0.036084
# P19A        52.250000         2.626501  0.601387   0.048244
# P20A        74.000000         3.956570  0.841641   0.085335
# P21A        64.000000         2.822554  0.660108   0.049866
# P22A        22.000000         2.751392  0.774806   0.201846
#
#            observed_features  fisher_alpha
# Sample ID
# P01A                    72.0      9.878377
# P03A                   128.0     19.343215
# P05A                    56.0      7.389004
# P07A                   182.0     29.349853
# P09A                    68.0      9.245668
# P11A                    76.0     10.517590
# P13A                   187.0     30.313820
# P15A                    64.0      8.619693
# P17A                    84.0     11.814705
# P19A                    52.0      6.784896
# P20A                    74.0     10.197184
# P21A                    59.0      7.847089
# P22A                    22.0      2.545015

# %%
ndf = df.merge(sample_metadata.to_dataframe(), left_index=True, right_index=True)
# ndf["color"] = ndf.groupby("population").ngroup()
# ndf.reset_index().plot.scatter("index", "observed_features", c="color", cmap=plt.cm.viridis)

# %%
col = 'observed_features'
meta_cols = ['year', 'population']
df1 = ndf[meta_cols + [col]].rename(columns={col: 'value'}).eval('type=@col')

col = 'chao1'
df2 = ndf[meta_cols + [col]].rename(columns={col: 'value'}).eval('type=@col')

df = pd.concat([df1, df2])
df
# Out:
#            year               population       value               type
# Sample ID
# P01A       2015  linija reke Ljubljanice   72.000000  observed_features
# P03A       2015  linija reke Ljubljanice  128.000000  observed_features
# P05A       2016         dolenjska linija   56.000000  observed_features
# P07A       2017  linija reke Ljubljanice  182.000000  observed_features
# P09A       2019  linija reke Ljubljanice   68.000000  observed_features
# P11A       2018  linija reke Ljubljanice   76.000000  observed_features
# P13A       2019  linija reke Ljubljanice  187.000000  observed_features
# P15A       2019  linija reke Ljubljanice   64.000000  observed_features
# P17A       2019  linija reke Ljubljanice   84.000000  observed_features
# P19A       2016            črna podvrsta   52.000000  observed_features
# P20A       2016            črna podvrsta   74.000000  observed_features
# P21A       2015            črna podvrsta   59.000000  observed_features
# P22A       2020            črna podvrsta   22.000000  observed_features
# P01A       2015  linija reke Ljubljanice   84.000000              chao1
# P03A       2015  linija reke Ljubljanice  130.000000              chao1
# P05A       2016         dolenjska linija   56.200000              chao1
# P07A       2017  linija reke Ljubljanice  186.090909              chao1
# P09A       2019  linija reke Ljubljanice   71.500000              chao1
# P11A       2018  linija reke Ljubljanice   79.000000              chao1
# P13A       2019  linija reke Ljubljanice  190.500000              chao1
# P15A       2019  linija reke Ljubljanice   64.000000              chao1
# P17A       2019  linija reke Ljubljanice   85.666667              chao1
# P19A       2016            črna podvrsta   52.250000              chao1
# P20A       2016            črna podvrsta   74.000000              chao1
# P21A       2015            črna podvrsta   64.000000              chao1
# P22A       2020            črna podvrsta   22.000000              chao1

# %%
from plotnine import *
from plotnine.data import *

p = (
    ggplot(df, aes(x=df.index, y='value', shape='year', color='population', alpha='type'))
    + geom_point(size=4)
    + labs(x='Sample ID', y='Value')
    + scale_color_manual(['C0', 'C1', 'C2'])
    + scale_alpha_manual([0.3, 1.0])
)

p.save('./results/eukarya_obs-feat_chao1.png')

p
# Out:
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/plotnine/ggplot.py:719: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/plotnine/ggplot.py:722: PlotnineWarning: Filename: ./results/eukarya_obs-feat_chao1.png
# <ggplot: (8747507405650)>

# %%
shannon = (
    ggplot(ndf, aes(x=ndf.index, y='shannon_entropy', shape='year', color='population'))
    + geom_point(size=4)
    + labs(x='Sample ID', y='shannon_entropy')
    + scale_color_manual(['C0', 'C1', 'C2'])
)

shannon.save('./results/eukarya_shannon.png')
shannon
# Out:
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/plotnine/ggplot.py:719: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/plotnine/ggplot.py:722: PlotnineWarning: Filename: ./results/eukarya_shannon.png
# <ggplot: (8747741620872)>

# %%
simpson = (
    ggplot(ndf, aes(x=ndf.index, y='simpson_e', shape='year', color='population'))
    + geom_point(size=4)
    + labs(x='Sample ID', y='simpson_e')
    + scale_color_manual(['C0', 'C1', 'C2'])
    + ylim(0,1)
)

simpson.save('./results/eukarya_simpson_e.png')
simpson
# Out:
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/plotnine/ggplot.py:719: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/plotnine/ggplot.py:722: PlotnineWarning: Filename: ./results/eukarya_simpson_e.png
# <ggplot: (8747678160689)>

# %%
# visualisations of alpha diversity metrics
visualizations = {}

for key, value in artifacts.items():
    visualizations[key] = diversity.visualizers.alpha_group_significance(
        alpha_diversity = value,
        metadata = sample_metadata
    ).visualization

# %%
# # simpson viz
# visualizations['simpson']

# # observed_features viz
# visualizations['observed_features']

# # fisher_alpha viz
# visualizations['fisher_alpha']

# # chao1 viz
# visualizations['chao1']

# # shannon viz
# visualizations['shannon']

# # evenness_vector viz
# diversity.visualizers.alpha_group_significance(
#     alpha_diversity = action_results.evenness_vector,
#     metadata = sample_metadata
# ).visualization

# # faith_pd viz
# diversity.visualizers.alpha_group_significance(
#     alpha_diversity = action_results.faith_pd_vector,
#     metadata = sample_metadata
# ).visualization

# %% [markdown]
# ### BETA DIVERSITY

# %%
denoisetable_subset_population = q2.plugins.feature_table.methods.filter_samples(
    table = denoisetable_eu,
    metadata = sample_metadata,
    where = "[population] IN ('linija reke Ljubljanice', 'črna podvrsta')"
)

# %%
# 2016 falls out
denoisetable_subset_year = q2.plugins.feature_table.methods.filter_samples(
    table = denoisetable_eu,
    metadata = sample_metadata,
    where = "[year] IN ('2015','2019')"
)

# %%
# determine depth/s from alpha_rarefaction
# determine conditions from metadata column names
depth = 14448
condition = 'population'

core_metrics_results_subset_population = diversity.actions.core_metrics_phylogenetic(
    phylogeny = rooted_tree,
    table = denoisetable_subset_population.filtered_table,
    sampling_depth = depth,
    metadata = sample_metadata
)
# Out:
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:1776: DataConversionWarning: Data was converted to boolean for metric jaccard
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /tmp/qiime2-archive-sc4y1xxg/639e27fb-2ad2-41e1-8c0f-b787451742e7/data/feature-table.biom -t /tmp/qiime2-archive-ww1jz9ue/705f2128-028c-4219-902a-fd476faf6e8a/data/tree.nwk -o /tmp/q2-AlphaDiversityFormat-ybv35h1a
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-sc4y1xxg/639e27fb-2ad2-41e1-8c0f-b787451742e7/data/feature-table.biom -t /tmp/qiime2-archive-ww1jz9ue/705f2128-028c-4219-902a-fd476faf6e8a/data/tree.nwk -m unweighted -o /tmp/q2-LSMatFormat-33xfg727
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-sc4y1xxg/639e27fb-2ad2-41e1-8c0f-b787451742e7/data/feature-table.biom -t /tmp/qiime2-archive-ww1jz9ue/705f2128-028c-4219-902a-fd476faf6e8a/data/tree.nwk -m weighted_unnormalized -o /tmp/q2-LSMatFormat-3wx8xzfy
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:143: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.001909243701353222 and the largest is 0.3588669098673588.

# %%
depth = 14448
condition = 'year'

core_metrics_results_subset_year = diversity.actions.core_metrics_phylogenetic(
    phylogeny = rooted_tree,
    table = denoisetable_subset_year.filtered_table,
    sampling_depth = depth,
    metadata = sample_metadata
)
# Out:
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:1776: DataConversionWarning: Data was converted to boolean for metric jaccard
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /tmp/qiime2-archive-nglh8uqv/e129a94f-be1b-4af4-93b4-249fec730319/data/feature-table.biom -t /tmp/qiime2-archive-ww1jz9ue/705f2128-028c-4219-902a-fd476faf6e8a/data/tree.nwk -o /tmp/q2-AlphaDiversityFormat-vstvpp_j
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-nglh8uqv/e129a94f-be1b-4af4-93b4-249fec730319/data/feature-table.biom -t /tmp/qiime2-archive-ww1jz9ue/705f2128-028c-4219-902a-fd476faf6e8a/data/tree.nwk -m unweighted -o /tmp/q2-LSMatFormat-ww9nfiwe
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /tmp/qiime2-archive-nglh8uqv/e129a94f-be1b-4af4-93b4-249fec730319/data/feature-table.biom -t /tmp/qiime2-archive-ww1jz9ue/705f2128-028c-4219-902a-fd476faf6e8a/data/tree.nwk -m weighted_unnormalized -o /tmp/q2-LSMatFormat-fsavkp84
# /opt/miniconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:143: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0016282441168183146 and the largest is 0.29680565801815306.

# %% [markdown]
# #### PERMANOVA

# %%
from qiime2.plugins.diversity.visualizers import beta_group_significance

permanova_population = beta_group_significance(
    distance_matrix = core_metrics_results_subset_population.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata.get_column('population'),
    method = "permanova",
    pairwise = True
)
permanova_population.visualization
# Out:
# <visualization: Visualization uuid: fd84f6e2-f030-4b42-b2fa-45f3d939cb94>

# %%
# PERMANOVA year
from qiime2.plugins.diversity.visualizers import beta_group_significance

permanova_year = beta_group_significance(
    distance_matrix = core_metrics_results_subset_year.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata.get_column('year'),
    method = "permanova",
    pairwise = True
)
permanova_year.visualization
# Out:
# <visualization: Visualization uuid: 50d494f1-b3b2-418b-b99c-60a45839debb>

# %% [markdown]
# #### ANOSIM

# %%
anosim_population = beta_group_significance(
    distance_matrix = core_metrics_results_subset_population.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata.get_column('population'),
    method = "anosim",
    pairwise = True
)
anosim_population.visualization
# Out:
# <visualization: Visualization uuid: 074fdc78-4aa1-4e44-adab-da0b215a900d>

# %%
# anosim year

anosim_year = beta_group_significance(
    distance_matrix = core_metrics_results_subset_year.unweighted_unifrac_distance_matrix,
    metadata = sample_metadata.get_column('year'),
    method = "anosim",
    pairwise = True
)
anosim_year.visualization
# Out:
# <visualization: Visualization uuid: fcd5a7c9-0b64-4453-8e93-fe1a512dba96>
